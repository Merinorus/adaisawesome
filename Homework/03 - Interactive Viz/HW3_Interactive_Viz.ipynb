# %% [markdown]
# (1) Build a Choropleth map which shows intuitively (i.e., use colors wisely) how much grant money goes to each Swiss canton. First we will need to get the data ready, which means determining which canton wach university is at and summing up the grant amounts by canton.

# %%
import pandas as pd
import numpy as np
# We will read json files, for instance API keys stored in our computers for using Google Maps API, so they're not publicly visible
import json
# Geolocation
import geopy
from geopy.geocoders import geonames
import math
import logging

# %%
p3_grant_export_data = pd.read_csv("P3_GrantExport.csv", sep=";")
p3_grant_export_data
# Out:
#        ﻿"Project Number"                                      Project Title  \
# 0                      1  Schlussband (Bd. VI) der Jacob Burckhardt-Biog...
# 1                      4  Batterie de tests à l'usage des enseignants po...
# 2                      5  Kritische Erstausgabe der "Evidentiae contra D...
# 3                      6  Katalog der datierten Handschriften in der Sch...
# 4                      7  Wissenschaftliche Mitarbeit am Thesaurus Lingu...
# 5                      8  Die schweizerische Wirtschaftspolitik seit dem...
# 6                      9  Theologische Forschungen zur Oekumene (Studien...
# 7                     10  Konfuzianische Kulturwerte in der sozialen Ent...
# 8                     11  Edizione degli scritti di Aurelio de' Giorgi B...
# 9                     13  La construction de nouveautés au sein des morp...
# 10                    14  Wissensstruktur, Fragegenese und Wissenserweit...
# 11                    17  Rechtsquellenkommission des Schweizerischen Ju...
# 12                    18  L'école et la vie: examens pédagogiques des re...
# 13                    19    Das Ringen um soziale Sicherheit in der Schweiz
# 14                    20  Kolloquium zum Thema "Ein System Sozialer Indi...
# 15                    21  Struktur und Funktion didaktischer Bezugssyste...
# 16                    23  Psycholinguistique génétique: l'évolution des ...
# 17                    25  Grösse, Verwaltungsstruktur und Entwicklung sc...
# 18                    26  Rollendifferenzierung bei Schweizer Ehepaaren ...
# 19                    27  Déviants sociaux et culturels, réseaux lausannois
# 20                    28  Evaluation de quelques objectifs d'une école e...
# 21                    30  Werte und Wertordnungen in der schweizerischen...
# 22                    32  Der Einfluss kleinstaatlicher Bedingungen auf ...
# 23                    33  Etude des instruments heuristiques propres à f...
# 24                    34  Die Haltung der Schweiz im Kalten Krieg (1945-...
# 25                    35  L'italiano regionale del canton Ticino.Ricerca...
# 26                    36          Aktion Bauernhausforschung in der Schweiz
# 27                    37  Erschliessung und Inventarisierung des Nachlas...
# 28                    38  Hateruma, sozio-religiöse Aspekte einer Inselk...
# 29                    39  Chronologie und Oekologie schweizerischer ur- ...
# ...                  ...                                                ...
# 63939             170414  Gleichstellungspolitik öffentlicher Arbeitgebe...
# 63940             170473  Johann Ferdinand Schor und seine Architekturma...
# 63941             170478  Cascading uncertainties in coupled component m...
# 63942             170510  Ist Addieren schwieriger als Multiplizieren in...
# 63943             170707     Halogenated Greenhouse Gases on a Global Scale
# 63944             170714  Modern Dance and Hollywood. A Transatlantic Ap...
# 63945             170715  Evolving bedrock erosion from modelled cosmoge...
# 63946             170716  The creation of a thick labor market between S...
# 63947             170718  Unraveling the mechanism of dendritic cell mat...
# 63948             170762  Effect of Material, Pore Size, and Configurati...
# 63949             170806  Spatial and temporal dynamics of N2O fluxes an...
# 63950             170812   Formes d'Europe : de l'Union européenne et d'...
# 63951             170813  NRP68 partial synthesis on spatial development...
# 63952             170814  Thematic Synthesis NRP68: Soil Data, Methods a...
# 63953             170815  Towards Sustainable Soil Policy - Thematic Syn...
# 63954             170817  Genomics of temperature tolerance in the ecolo...
# 63955             170883  Does Religion Make a Difference? Discourses an...
# 63956             170893  Cortical EEG- and MEG-sources of complex menta...
# 63957             170894  Towards the fetal connectome: developing diffu...
# 63958             170953  Conference "Human : Non-Human: Body, things, a...
# 63959             171009  Inventer la littérature médiévale (XVIe-XVIIe ...
# 63960             171100  Numerical and field study of Argentinian and N...
# 63961             171106  Anisotropic particles at fluid interfaces: the...
# 63962             171112  From the barricades into politics: the role of...
# 63963             171113                          La fin de l'intériorité ?
# 63964             171114                  Faulheit – Spielformen des Faulen
# 63965             171126               Sound Colour Space - Abschlusstagung
# 63966             171130  Combining Brain-Computer Interfaces and Neurom...
# 63967             171131  Computational optimization of a model-based in...
# 63968             171414  Growth Kinetics Interaction of Staphylococcus ...
#
#                                    Project Title English  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 13                                                   NaN
# 14                                                   NaN
# 15                                                   NaN
# 16                                                   NaN
# 17                                                   NaN
# 18                                                   NaN
# 19                                                   NaN
# 20                                                   NaN
# 21                                                   NaN
# 22                                                   NaN
# 23                                                   NaN
# 24                                                   NaN
# 25                                                   NaN
# 26                                                   NaN
# 27                                                   NaN
# 28                                                   NaN
# 29                                                   NaN
# ...                                                  ...
# 63939  Equal Opportunity Policies of Public Employers...
# 63940  Johann Ferdinand Schor and his Architectural T...
# 63941  Cascading uncertainties in coupled component m...
# 63942  Is addying more difficult than multiplying in ...
# 63943     Halogenated Greenhouse Gases on a Global Scale
# 63944  Modern Dance and Hollywood. A Transatlantic Ap...
# 63945  Evolving bedrock erosion from modelled cosmoge...
# 63946  The creation of a thick labor market between S...
# 63947  Unraveling the mechanism of dendritic cell mat...
# 63948  Effect of Material, Pore Size, and Configurati...
# 63949  Spatial and temporal dynamics of N2O fluxes an...
# 63950  Forms of Europe : of the European Union and of...
# 63951  NRP68 partial synthesis on spatial development...
# 63952                                                NaN
# 63953                                                NaN
# 63954  Genomics of temperature tolerance in the ecolo...
# 63955  Does Religion Make a Difference? Discourses an...
# 63956  Cortical EEG- and MEG-sources of complex menta...
# 63957  Towards the fetal connectome: developing diffu...
# 63958                                                NaN
# 63959  Inventing medieval literature (16th-17th century)
# 63960  Numerical and field study of Argentinian and N...
# 63961  Anisotropic particles at fluid interfaces: the...
# 63962  From the barricades into politics: the role of...
# 63963                          La fin de l'intériorité ?
# 63964                                                NaN
# 63965              Sound Colour Space - Final Conference
# 63966  Combining Brain-Computer Interfaces and Neurom...
# 63967  Computational optimization of a model-based in...
# 63968  Growth Kinetics Interaction of Staphylococcus ...
#
#                                    Responsible Applicant  \
# 0                                           Kaegi Werner
# 1                                     Massarenti Léonard
# 2      Kommission für das Corpus philosophorum medii ...
# 3                                         Burckhardt Max
# 4                           Schweiz. Thesauruskommission
# 5                                    Kleinewefers Henner
# 6                                    Stirnimann Heinrich
# 7                                       Deuchler Martina
# 8                                        Stäuble Antonio
# 9                                            Piaget Jean
# 10                                        Flammer August
# 11     Schweizerische Rechtsquellen c/o Universität Z...
# 12                                           Girod Roger
# 13                                         Borner Silvio
# 14                         Hoffmann-Nowotny Hans-Joachim
# 15                                         Santini Bruno
# 16                                      Sinclair Hermina
# 17                                          Heintz Peter
# 18                                     Unteregger Judith
# 19                                       Willener Alfred
# 20                                      Huberman Michael
# 21                                          Rüegg Walter
# 22                                           Frei Daniel
# 23                                           Roulet Eddy
# 24                                         Bonjour Edgar
# 25                                       Bianconi Sandro
# 26            Schweizerische Gesellschaft für Volkskunde
# 27                         Kuratorium Carl J. Burckhardt
# 28                                    Ouwehand Cornelius
# 29                                       Bosshard Walter
# ...                                                  ...
# 63939                                       Fuchs Gesine
# 63940                                   Šterbová Daniela
# 63941                                Zischg Andreas Paul
# 63942                                     Ziegler Esther
# 63943                                  Vollmer Martin K.
# 63944                                    Köhler Kristina
# 63945                               Norton Kevin Patrick
# 63946                                     Beerli Andreas
# 63947                                   Kashyap Abhishek
# 63948                                         Howe Kerry
# 63949                                   Barthel Matthias
# 63950                                        Grin Gilles
# 63951                              Grêt-Regamey Adrienne
# 63952                                       Keller Armin
# 63953                                       Walter Felix
# 63954                                      Yampolsky Lev
# 63955                                   Köhrsen Jens-Ole
# 63956                                      Milz Patricia
# 63957                          Kuklisova Murgasova Maria
# 63958                                   Malinar Angelika
# 63959                                      Dahhaoui Yann
# 63960                                     Manzella Irene
# 63961                                      Senbil Nesrin
# 63962                                  Grano Simona Alba
# 63963                                   Pierron Nathalie
# 63964                                     Stetter Bitten
# 63965                                      Neukom Martin
# 63966                                 Millán José del R.
# 63967                             Szilágyi Sándor Miklós
# 63968                                        Frey Pascal
#
#                                  Funding Instrument  \
# 0                      Project funding (Div. I-III)
# 1                      Project funding (Div. I-III)
# 2                      Project funding (Div. I-III)
# 3                      Project funding (Div. I-III)
# 4                      Project funding (Div. I-III)
# 5                      Project funding (Div. I-III)
# 6                      Project funding (Div. I-III)
# 7                      Project funding (Div. I-III)
# 8                      Project funding (Div. I-III)
# 9                      Project funding (Div. I-III)
# 10                     Project funding (Div. I-III)
# 11                     Project funding (Div. I-III)
# 12                     Project funding (Div. I-III)
# 13                     Project funding (Div. I-III)
# 14                     Project funding (Div. I-III)
# 15                     Project funding (Div. I-III)
# 16                     Project funding (Div. I-III)
# 17                     Project funding (Div. I-III)
# 18                     Project funding (Div. I-III)
# 19                     Project funding (Div. I-III)
# 20                     Project funding (Div. I-III)
# 21                     Project funding (Div. I-III)
# 22                     Project funding (Div. I-III)
# 23                     Project funding (Div. I-III)
# 24                     Project funding (Div. I-III)
# 25                     Project funding (Div. I-III)
# 26                     Project funding (Div. I-III)
# 27                     Project funding (Div. I-III)
# 28                     Project funding (Div. I-III)
# 29                     Project funding (Div. I-III)
# ...                                             ...
# 63939                            Publication grants
# 63940           International short research visits
# 63941           International short research visits
# 63942           International short research visits
# 63943           International short research visits
# 63944           International short research visits
# 63945           International short research visits
# 63946           International short research visits
# 63947           International short research visits
# 63948           International short research visits
# 63949           International short research visits
# 63950                        Scientific Conferences
# 63951  NRP 68 Sustainable Use of Soil as a Resource
# 63952  NRP 68 Sustainable Use of Soil as a Resource
# 63953  NRP 68 Sustainable Use of Soil as a Resource
# 63954           International short research visits
# 63955           International Exploratory Workshops
# 63956           International short research visits
# 63957           International short research visits
# 63958                        Scientific Conferences
# 63959                        Scientific Conferences
# 63960           International short research visits
# 63961           International short research visits
# 63962           International short research visits
# 63963                        Scientific Conferences
# 63964                        Scientific Conferences
# 63965                        Scientific Conferences
# 63966           International short research visits
# 63967           International short research visits
# 63968           International short research visits
#
#                          Funding Instrument Hierarchy  \
# 0                                     Project funding
# 1                                     Project funding
# 2                                     Project funding
# 3                                     Project funding
# 4                                     Project funding
# 5                                     Project funding
# 6                                     Project funding
# 7                                     Project funding
# 8                                     Project funding
# 9                                     Project funding
# 10                                    Project funding
# 11                                    Project funding
# 12                                    Project funding
# 13                                    Project funding
# 14                                    Project funding
# 15                                    Project funding
# 16                                    Project funding
# 17                                    Project funding
# 18                                    Project funding
# 19                                    Project funding
# 20                                    Project funding
# 21                                    Project funding
# 22                                    Project funding
# 23                                    Project funding
# 24                                    Project funding
# 25                                    Project funding
# 26                                    Project funding
# 27                                    Project funding
# 28                                    Project funding
# 29                                    Project funding
# ...                                               ...
# 63939                           Science communication
# 63940                                         Careers
# 63941                                         Careers
# 63942                                         Careers
# 63943                                         Careers
# 63944                                         Careers
# 63945                                         Careers
# 63946                                         Careers
# 63947                                         Careers
# 63948                                         Careers
# 63949                                         Careers
# 63950                           Science communication
# 63951  Programmes;National Research Programmes (NRPs)
# 63952  Programmes;National Research Programmes (NRPs)
# 63953  Programmes;National Research Programmes (NRPs)
# 63954                                         Careers
# 63955                           Science communication
# 63956                                         Careers
# 63957                                         Careers
# 63958                           Science communication
# 63959                           Science communication
# 63960                                         Careers
# 63961                                         Careers
# 63962                                         Careers
# 63963                           Science communication
# 63964                           Science communication
# 63965                           Science communication
# 63966                                         Careers
# 63967                                         Careers
# 63968                                         Careers
#
#                                              Institution  \
# 0                                                    NaN
# 1      Faculté de Psychologie et des Sciences de l'Ed...
# 2      Kommission für das Corpus philosophorum medii ...
# 3      Abt. Handschriften und Alte Drucke Bibliothek ...
# 4                           Schweiz. Thesauruskommission
# 5      Séminaire de politique économique, d'économie ...
# 6      Institut für ökumenische Studien Université de...
# 7              Ostasiatisches Seminar Universität Zürich
# 8                                                    NaN
# 9      Laboratoire de Didactique et Epistémologie des...
# 10     Klinische Psychologie und Psychotherapie Insti...
# 11     Schweizerische Rechtsquellen c/o Universität Z...
# 12     Département de Sociologie Faculté des Sciences...
# 13     Institut für Volkswirtschaft WWZ / FGS Univers...
# 14            Soziologisches Institut Universität Zürich
# 15                                 Forschungszentrum FAL
# 16     Faculté de Psychologie et des Sciences de l'Ed...
# 17            Soziologisches Institut Universität Zürich
# 18                                                   NaN
# 19                                                   NaN
# 20     Faculté de Psychologie et des Sciences de l'Ed...
# 21                                                   NaN
# 22     Forschungsbereich Politisches Verhalten und Oe...
# 23     Département des langues et des littératures fr...
# 24                                                   NaN
# 25                                                   NaN
# 26            Schweizerische Gesellschaft für Volkskunde
# 27                         Kuratorium Carl J. Burckhardt
# 28                                                   NaN
# 29     Eidg. Forschungsanstalt für Wald, Schnee und L...
# ...                                                  ...
# 63939  Institut Sozialmanagement und Sozialpolitik Ho...
# 63940                Stiftung Bibliothek Werner Oechslin
# 63941  School of Geographical Sciences University of ...
# 63942                                                NaN
# 63943              CSIRO Marine and Atmospheric Research
# 63944                                                NaN
# 63945     Departement Geographie, SIE Universität Zürich
# 63946  CReAM Department of Economics University Colle...
# 63947                                                NaN
# 63948                                              Eawag
# 63949                      Catholic University of Bukavu
# 63950  Fondation Jean Monnet pour l'Europe Centre de ...
# 63951  Planning of Landscape and Urban Systems Instit...
# 63952  Forschungsanstalt Agroscope Reckenholz-Tänikon...
# 63953  Forschung und Beratung in Wirtschaft und Polit...
# 63954            Zoologisches Institut Universität Basel
# 63955  Zentrum für Religion, Wirtschaft und Politik T...
# 63956  Abteilung für Neuropsychologie Zentrum für Kog...
# 63957                                                NaN
# 63958         Abteilung für Indologie Universität Zürich
# 63959  Institut Religions, Cultures, Modernité FTSR U...
# 63960                                                NaN
# 63961  Department of Physics University of Massachusetts
# 63962                                                NaN
# 63963     Haute École d'art et de design - Genève HES-SO
# 63964  Departement Design Zürcher Hochschule der Küns...
# 63965  Institute Performing Arts and Film Zürcher Hoc...
# 63966  Department of Electrical Engineering and Compu...
# 63967  Département de Biologie Faculté des Sciences U...
# 63968  The Forsyth Institute Department of Microbiolo...
#
#                                               University  Discipline Number  \
# 0                                   Nicht zuteilbar - NA              10302
# 1                              Université de Genève - GE              10104
# 2                NPO (Biblioth., Museen, Verwalt.) - NPO              10101
# 3                                 Universität Basel - BS              10302
# 4                NPO (Biblioth., Museen, Verwalt.) - NPO              10303
# 5                            Université de Fribourg - FR              10203
# 6                            Université de Fribourg - FR              10102
# 7                                Universität Zürich - ZH              10301
# 8                            Université de Lausanne - LA              10502
# 9                              Université de Genève - GE              10105
# 10                           Université de Fribourg - FR              10105
# 11               NPO (Biblioth., Museen, Verwalt.) - NPO              10205
# 12                             Université de Genève - GE              10201
# 13                                Universität Basel - BS              10203
# 14                               Universität Zürich - ZH              10201
# 15                           Université de Fribourg - FR              10104
# 16                             Université de Genève - GE              10105
# 17                               Universität Zürich - ZH              10201
# 18                                  Nicht zuteilbar - NA              10201
# 19                           Université de Lausanne - LA              10201
# 20                             Université de Genève - GE              10104
# 21                                 Universität Bern - BE              10201
# 22                               Universität Zürich - ZH              10202
# 23                             Université de Genève - GE              10502
# 24                                  Nicht zuteilbar - NA              10302
# 25                                  Nicht zuteilbar - NA              10502
# 26               NPO (Biblioth., Museen, Verwalt.) - NPO              10403
# 27               NPO (Biblioth., Museen, Verwalt.) - NPO              10302
# 28                               Universität Zürich - ZH              10403
# 29     Eidg. Forschungsanstalt für Wald,Schnee,Land -...              10402
# ...                                                  ...                ...
# 63939                           Hochschule Luzern - HSLU              10202
# 63940                                                NaN              10407
# 63941                                                NaN              20705
# 63942                                                NaN              10105
# 63943                                                NaN              20704
# 63944                                                NaN              10406
# 63945                                                NaN              20702
# 63946                                                NaN              10203
# 63947                                                NaN              30103
# 63948                                                NaN              20511
# 63949                                                NaN              20701
# 63950            NPO (Biblioth., Museen, Verwalt.) - NPO              10202
# 63951                                  ETH Zürich - ETHZ              20511
# 63952                Forschungsanstalten Agroscope - AGS              20701
# 63953                       Firmen/Privatwirtschaft - FP              10202
# 63954                                                NaN              30202
# 63955                             Universität Basel - BS              10102
# 63956                                                NaN              30302
# 63957                                                NaN              20504
# 63958                            Universität Zürich - ZH              10503
# 63959                        Université de Lausanne - LA              10301
# 63960                                                NaN              20801
# 63961                                                NaN              20409
# 63962                                                NaN              10202
# 63963                 HES de Suisse occidentale - HES-SO              10603
# 63964             Zürcher Fachhochschule (ohne PH) - ZFH              10603
# 63965             Zürcher Fachhochschule (ohne PH) - ZFH              10604
# 63966                                                NaN              20511
# 63967                                                NaN              30102
# 63968                                                NaN              30307
#
#                                        Discipline Name  \
# 0                                        Swiss history
# 1                     Educational science and Pedagogy
# 2                                           Philosophy
# 3                                        Swiss history
# 4                Ancient history and Classical studies
# 5                                            Economics
# 6                         Religious sciences, Theology
# 7                                   History in general
# 8                     Romance languages and literature
# 9                                           Psychology
# 10                                          Psychology
# 11                                      Legal sciences
# 12                                           Sociology
# 13                                           Economics
# 14                                           Sociology
# 15                    Educational science and Pedagogy
# 16                                          Psychology
# 17                                           Sociology
# 18                                           Sociology
# 19                                           Sociology
# 20                    Educational science and Pedagogy
# 21                                           Sociology
# 22                                   Political science
# 23                    Romance languages and literature
# 24                                       Swiss history
# 25                    Romance languages and literature
# 26                                           Ethnology
# 27                                       Swiss history
# 28                                           Ethnology
# 29                                         Archaeology
# ...                                                ...
# 63939                                Political science
# 63940            Architecture and Social urban science
# 63941                 Hydrology, Limnology, Glaciology
# 63942                                       Psychology
# 63943  Climatology. Atmospherical Chemistry, Aeronomoy
# 63944                               Theater and Cinema
# 63945                                    Geomorphology
# 63946                                        Economics
# 63947                       Cellular Biology, Cytology
# 63948        Other disciplines of Engineering Sciences
# 63949                                         Pedology
# 63950                                Political science
# 63951        Other disciplines of Engineering Sciences
# 63952                                         Pedology
# 63953                                Political science
# 63954                                          Zoology
# 63955                     Religious sciences, Theology
# 63956               Neurophysiology and Brain Research
# 63957                           Electrical Engineering
# 63958                   Other languages and literature
# 63959                               History in general
# 63960                                          Geology
# 63961                     Other disciplines of Physics
# 63962                                Political science
# 63963                                             Arts
# 63964                                             Arts
# 63965                                   Music, Theatre
# 63966        Other disciplines of Engineering Sciences
# 63967                                Molecular Biology
# 63968                             Medical Microbiology
#
#                                Discipline Name Hierarchy  Start Date  \
# 0      Human and Social Sciences;Theology & religious...  01.10.1975
# 1      Human and Social Sciences;Psychology, educatio...  01.10.1975
# 2      Human and Social Sciences;Linguistics and lite...  01.03.1976
# 3      Human and Social Sciences;Theology & religious...  01.10.1975
# 4      Human and Social Sciences;Theology & religious...  01.01.1976
# 5               Human and Social Sciences;Economics, law  01.01.1976
# 6      Human and Social Sciences;Theology & religious...  01.01.1976
# 7      Human and Social Sciences;Theology & religious...  01.10.1975
# 8      Human and Social Sciences;Linguistics and lite...  01.10.1975
# 9      Human and Social Sciences;Psychology, educatio...  01.10.1975
# 10     Human and Social Sciences;Psychology, educatio...  01.10.1975
# 11              Human and Social Sciences;Economics, law  01.10.1975
# 12     Human and Social Sciences;Sociology, social wo...  01.10.1975
# 13              Human and Social Sciences;Economics, law  01.10.1975
# 14     Human and Social Sciences;Sociology, social wo...  01.10.1975
# 15     Human and Social Sciences;Psychology, educatio...  01.10.1975
# 16     Human and Social Sciences;Psychology, educatio...  01.10.1975
# 17     Human and Social Sciences;Sociology, social wo...  01.01.1976
# 18     Human and Social Sciences;Sociology, social wo...  01.01.1976
# 19     Human and Social Sciences;Sociology, social wo...  01.12.1975
# 20     Human and Social Sciences;Psychology, educatio...  01.10.1975
# 21     Human and Social Sciences;Sociology, social wo...  01.10.1975
# 22     Human and Social Sciences;Sociology, social wo...  01.01.1976
# 23     Human and Social Sciences;Linguistics and lite...  01.10.1975
# 24     Human and Social Sciences;Theology & religious...  01.01.1976
# 25     Human and Social Sciences;Linguistics and lite...  01.10.1975
# 26     Human and Social Sciences;Ethnology, social an...  01.10.1975
# 27     Human and Social Sciences;Theology & religious...  01.10.1975
# 28     Human and Social Sciences;Ethnology, social an...  01.10.1975
# 29     Human and Social Sciences;Theology & religious...  01.10.1975
# ...                                                  ...         ...
# 63939  Human and Social Sciences;Sociology, social wo...  01.08.2016
# 63940  Human and Social Sciences;Art studies, musicol...  01.07.2016
# 63941  Mathematics, Natural- and Engineering Sciences...  01.08.2016
# 63942  Human and Social Sciences;Psychology, educatio...  01.07.2016
# 63943  Mathematics, Natural- and Engineering Sciences...  01.08.2016
# 63944  Human and Social Sciences;Art studies, musicol...  01.07.2016
# 63945  Mathematics, Natural- and Engineering Sciences...  01.08.2016
# 63946           Human and Social Sciences;Economics, law  01.09.2016
# 63947     Biology and Medicine;Basic Biological Research  01.08.2016
# 63948  Mathematics, Natural- and Engineering Sciences...  01.09.2016
# 63949  Mathematics, Natural- and Engineering Sciences...  01.09.2016
# 63950  Human and Social Sciences;Sociology, social wo...  01.10.2016
# 63951  Mathematics, Natural- and Engineering Sciences...  01.10.2016
# 63952  Mathematics, Natural- and Engineering Sciences...  01.10.2016
# 63953  Human and Social Sciences;Sociology, social wo...  01.09.2016
# 63954               Biology and Medicine;General Biology  01.09.2016
# 63955  Human and Social Sciences;Theology & religious...  01.10.2016
# 63956        Biology and Medicine;Basic Medical Sciences  01.08.2016
# 63957  Mathematics, Natural- and Engineering Sciences...  01.08.2016
# 63958  Human and Social Sciences;Linguistics and lite...  01.10.2016
# 63959  Human and Social Sciences;Theology & religious...  01.10.2016
# 63960  Mathematics, Natural- and Engineering Sciences...  01.10.2016
# 63961  Mathematics, Natural- and Engineering Sciences...  01.10.2016
# 63962  Human and Social Sciences;Sociology, social wo...  01.09.2016
# 63963  Human and Social Sciences;Art studies, musicol...  01.10.2016
# 63964  Human and Social Sciences;Art studies, musicol...  01.10.2016
# 63965  Human and Social Sciences;Art studies, musicol...  01.09.2016
# 63966  Mathematics, Natural- and Engineering Sciences...  01.09.2016
# 63967     Biology and Medicine;Basic Biological Research  01.09.2016
# 63968        Biology and Medicine;Basic Medical Sciences  01.10.2016
#
#          End Date Approved Amount  \
# 0      30.09.1976        11619.00
# 1      30.09.1976        41022.00
# 2      28.02.1985        79732.00
# 3      30.09.1976        52627.00
# 4      30.04.1978       120042.00
# 5      31.12.1978        53009.00
# 6      31.12.1976        25403.00
# 7      31.03.1977        47100.00
# 8      31.03.1977        25814.00
# 9      30.09.1978       360000.00
# 10     31.12.1978       153886.00
# 11     30.09.1978       862200.00
# 12     30.09.1977       116991.00
# 13     31.12.1978       112664.00
# 14     31.12.1975         5000.00
# 15     30.09.1977       204018.00
# 16     30.09.1977       149485.00
# 17     31.08.1977        83983.00
# 18     31.12.1976        38152.00
# 19     31.01.1977        14138.00
# 20     30.09.1978       164602.00
# 21     30.04.1978       147795.00
# 22     30.06.1977        24552.00
# 23     30.09.1978        44802.00
# 24     31.12.1979        56000.00
# 25     30.09.1977       152535.00
# 26     30.09.1976       225000.00
# 27     30.04.1978       179124.00
# 28     31.03.1976        20000.00
# 29     30.09.1978       445198.00
# ...           ...             ...
# 63939  31.07.2017         1898.00
# 63940  30.09.2016         9300.00
# 63941  31.10.2016         9500.00
# 63942  31.07.2016         4000.00
# 63943  31.10.2016        11000.00
# 63944  31.08.2016         7500.00
# 63945  30.09.2016         8000.00
# 63946  30.11.2016         9300.00
# 63947  30.09.2016         7000.00
# 63948  31.10.2016         6000.00
# 63949  30.09.2016         4500.00
# 63950  31.12.2016         2800.00
# 63951  30.09.2017        99952.00
# 63952  31.12.2017        98040.00
# 63953  28.02.2018       100000.00
# 63954  30.11.2016        10500.00
# 63955  31.12.2016        10030.00
# 63956  31.10.2016         7870.00
# 63957  31.08.2016         3150.00
# 63958  31.12.2016        10600.00
# 63959  31.12.2016         2515.00
# 63960  31.10.2016         3500.00
# 63961  31.10.2016         4000.00
# 63962  30.09.2016         3550.00
# 63963  31.12.2016         3000.00
# 63964  31.12.2016         1000.00
# 63965  30.11.2016         2000.00
# 63966  31.12.2016        10500.00
# 63967  30.11.2016         9500.00
# 63968  30.11.2016         7000.00
#
#                                                 Keywords
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 13                                                   NaN
# 14                                                   NaN
# 15                                                   NaN
# 16                                                   NaN
# 17                                                   NaN
# 18                                                   NaN
# 19                                                   NaN
# 20                                                   NaN
# 21                                                   NaN
# 22                                                   NaN
# 23                                                   NaN
# 24                                                   NaN
# 25                                                   NaN
# 26                                                   NaN
# 27                                                   NaN
# 28                                                   NaN
# 29                                                   NaN
# ...                                                  ...
# 63939  Gleichstellungspolitik;Betriebliche Gleichstel...
# 63940  Architectural education;Manuscripts of lecture...
# 63941  sensitivity analysis;uncertainty propagation i...
# 63942  Educational psychology;Mathematics instruction...
# 63943  mass spectrometry;hydrofluoroolefines;ozone de...
# 63944  Weimar Cinema;transatlantic cross-cultural tra...
# 63945  Surface exposure dating;10Be;Erosion;Modelling...
# 63946  thick labor market;agglomoration economies;fre...
# 63947  immunotherapy;dendritic cells;microtubule disr...
# 63948  gravity-driven membrane filtration;membrane fo...
# 63949      nitrous oxide;stable isotopes;eddy covariance
# 63950  Union européenne;intégration européenne;intégr...
# 63951          Synthesis;Spatial Planning;Soil resources
# 63952  soil survey;cost benefit analysis;soil informa...
# 63953  food production;governance;spatial development...
# 63954    Genomics;temperature;local adaptation;antioxida
# 63955  Religion;Development;Global South;Sustainabili...
# 63956  complex mental processing;EEG;MEG;inter-indivi...
# 63957  Diffusion MRI;In-vivo fetal imaging;Mathematic...
# 63958  Asia and Europe;Posthumanism;environmentalism;...
# 63959  Histoire des savoirs;Histoire de l'érudition;H...
# 63960  rock avalanches ;numerical modelling;field stu...
# 63961  fluid interfaces;anisotropic colloids;Contact ...
# 63962            Social activists;environmental politics
# 63963  architecture d'intérieur;espace;architecture;t...
# 63964  Cultural Studies;Sociology;Design Research;Phi...
# 63965  Diagrammatologie;Klangfarbe;Tonsysteme;Farbe/T...
# 63966  brain-computer interfaces;transcranical direct...
# 63967  Circadian Oscialltor;Delayed differential equa...
# 63968  Bacterial growth interaction;Dolosigranulum pi...
#
# [63969 rows x 15 columns]

# %%
# Here is the total number of rows we will have to deal with
len(p3_grant_export_data.index)
# Out:
# 63969

# %%
# We keep only the rows which mention how much money has been granted (the amount column starts by a number)
# ie : we keep rows where the 'Approved Amount' column starts with a number
p3_grant_export_data = p3_grant_export_data[p3_grant_export_data['Approved Amount'].apply(lambda x : x[0].isdigit())]

# %%
# Almost 200k rows have been removed
p3_grant_export_data.size
# Out:
# 795885

# %%
# We don't need this data
p3_grant_export_data = p3_grant_export_data.drop(p3_grant_export_data.columns[[0]], axis = 1)
p3_grant_export_data = p3_grant_export_data.drop(['Project Title', 'Project Title English', 'Responsible Applicant', 'Discipline Number', 'Discipline Name', 'Discipline Name Hierarchy', 'Keywords'], axis=1)
p3_grant_export_data.size
# Out:
# 371413

# %% [markdown]
# First, we will locate projcets according to the University name.
# We will ignore all project in which the University is not mentioned : we assume that if it's not, the project is probably outside Switzerland.
# If we have the time, a better solution would be taking the institution's location into account as well.

# %%
# Removing rows in which University is not mentioned
# p3_grant_export_data = p3_grant_export_data.dropna(subset=['University'])
# p3_grant_export_data.size

# %%
p3_grant_export_data
# Out:
#                                  Funding Instrument  \
# 0                      Project funding (Div. I-III)
# 1                      Project funding (Div. I-III)
# 2                      Project funding (Div. I-III)
# 3                      Project funding (Div. I-III)
# 4                      Project funding (Div. I-III)
# 5                      Project funding (Div. I-III)
# 6                      Project funding (Div. I-III)
# 7                      Project funding (Div. I-III)
# 8                      Project funding (Div. I-III)
# 9                      Project funding (Div. I-III)
# 10                     Project funding (Div. I-III)
# 11                     Project funding (Div. I-III)
# 12                     Project funding (Div. I-III)
# 13                     Project funding (Div. I-III)
# 14                     Project funding (Div. I-III)
# 15                     Project funding (Div. I-III)
# 16                     Project funding (Div. I-III)
# 17                     Project funding (Div. I-III)
# 18                     Project funding (Div. I-III)
# 19                     Project funding (Div. I-III)
# 20                     Project funding (Div. I-III)
# 21                     Project funding (Div. I-III)
# 22                     Project funding (Div. I-III)
# 23                     Project funding (Div. I-III)
# 24                     Project funding (Div. I-III)
# 25                     Project funding (Div. I-III)
# 26                     Project funding (Div. I-III)
# 27                     Project funding (Div. I-III)
# 28                     Project funding (Div. I-III)
# 29                     Project funding (Div. I-III)
# ...                                             ...
# 63939                            Publication grants
# 63940           International short research visits
# 63941           International short research visits
# 63942           International short research visits
# 63943           International short research visits
# 63944           International short research visits
# 63945           International short research visits
# 63946           International short research visits
# 63947           International short research visits
# 63948           International short research visits
# 63949           International short research visits
# 63950                        Scientific Conferences
# 63951  NRP 68 Sustainable Use of Soil as a Resource
# 63952  NRP 68 Sustainable Use of Soil as a Resource
# 63953  NRP 68 Sustainable Use of Soil as a Resource
# 63954           International short research visits
# 63955           International Exploratory Workshops
# 63956           International short research visits
# 63957           International short research visits
# 63958                        Scientific Conferences
# 63959                        Scientific Conferences
# 63960           International short research visits
# 63961           International short research visits
# 63962           International short research visits
# 63963                        Scientific Conferences
# 63964                        Scientific Conferences
# 63965                        Scientific Conferences
# 63966           International short research visits
# 63967           International short research visits
# 63968           International short research visits
#
#                          Funding Instrument Hierarchy  \
# 0                                     Project funding
# 1                                     Project funding
# 2                                     Project funding
# 3                                     Project funding
# 4                                     Project funding
# 5                                     Project funding
# 6                                     Project funding
# 7                                     Project funding
# 8                                     Project funding
# 9                                     Project funding
# 10                                    Project funding
# 11                                    Project funding
# 12                                    Project funding
# 13                                    Project funding
# 14                                    Project funding
# 15                                    Project funding
# 16                                    Project funding
# 17                                    Project funding
# 18                                    Project funding
# 19                                    Project funding
# 20                                    Project funding
# 21                                    Project funding
# 22                                    Project funding
# 23                                    Project funding
# 24                                    Project funding
# 25                                    Project funding
# 26                                    Project funding
# 27                                    Project funding
# 28                                    Project funding
# 29                                    Project funding
# ...                                               ...
# 63939                           Science communication
# 63940                                         Careers
# 63941                                         Careers
# 63942                                         Careers
# 63943                                         Careers
# 63944                                         Careers
# 63945                                         Careers
# 63946                                         Careers
# 63947                                         Careers
# 63948                                         Careers
# 63949                                         Careers
# 63950                           Science communication
# 63951  Programmes;National Research Programmes (NRPs)
# 63952  Programmes;National Research Programmes (NRPs)
# 63953  Programmes;National Research Programmes (NRPs)
# 63954                                         Careers
# 63955                           Science communication
# 63956                                         Careers
# 63957                                         Careers
# 63958                           Science communication
# 63959                           Science communication
# 63960                                         Careers
# 63961                                         Careers
# 63962                                         Careers
# 63963                           Science communication
# 63964                           Science communication
# 63965                           Science communication
# 63966                                         Careers
# 63967                                         Careers
# 63968                                         Careers
#
#                                              Institution  \
# 0                                                    NaN
# 1      Faculté de Psychologie et des Sciences de l'Ed...
# 2      Kommission für das Corpus philosophorum medii ...
# 3      Abt. Handschriften und Alte Drucke Bibliothek ...
# 4                           Schweiz. Thesauruskommission
# 5      Séminaire de politique économique, d'économie ...
# 6      Institut für ökumenische Studien Université de...
# 7              Ostasiatisches Seminar Universität Zürich
# 8                                                    NaN
# 9      Laboratoire de Didactique et Epistémologie des...
# 10     Klinische Psychologie und Psychotherapie Insti...
# 11     Schweizerische Rechtsquellen c/o Universität Z...
# 12     Département de Sociologie Faculté des Sciences...
# 13     Institut für Volkswirtschaft WWZ / FGS Univers...
# 14            Soziologisches Institut Universität Zürich
# 15                                 Forschungszentrum FAL
# 16     Faculté de Psychologie et des Sciences de l'Ed...
# 17            Soziologisches Institut Universität Zürich
# 18                                                   NaN
# 19                                                   NaN
# 20     Faculté de Psychologie et des Sciences de l'Ed...
# 21                                                   NaN
# 22     Forschungsbereich Politisches Verhalten und Oe...
# 23     Département des langues et des littératures fr...
# 24                                                   NaN
# 25                                                   NaN
# 26            Schweizerische Gesellschaft für Volkskunde
# 27                         Kuratorium Carl J. Burckhardt
# 28                                                   NaN
# 29     Eidg. Forschungsanstalt für Wald, Schnee und L...
# ...                                                  ...
# 63939  Institut Sozialmanagement und Sozialpolitik Ho...
# 63940                Stiftung Bibliothek Werner Oechslin
# 63941  School of Geographical Sciences University of ...
# 63942                                                NaN
# 63943              CSIRO Marine and Atmospheric Research
# 63944                                                NaN
# 63945     Departement Geographie, SIE Universität Zürich
# 63946  CReAM Department of Economics University Colle...
# 63947                                                NaN
# 63948                                              Eawag
# 63949                      Catholic University of Bukavu
# 63950  Fondation Jean Monnet pour l'Europe Centre de ...
# 63951  Planning of Landscape and Urban Systems Instit...
# 63952  Forschungsanstalt Agroscope Reckenholz-Tänikon...
# 63953  Forschung und Beratung in Wirtschaft und Polit...
# 63954            Zoologisches Institut Universität Basel
# 63955  Zentrum für Religion, Wirtschaft und Politik T...
# 63956  Abteilung für Neuropsychologie Zentrum für Kog...
# 63957                                                NaN
# 63958         Abteilung für Indologie Universität Zürich
# 63959  Institut Religions, Cultures, Modernité FTSR U...
# 63960                                                NaN
# 63961  Department of Physics University of Massachusetts
# 63962                                                NaN
# 63963     Haute École d'art et de design - Genève HES-SO
# 63964  Departement Design Zürcher Hochschule der Küns...
# 63965  Institute Performing Arts and Film Zürcher Hoc...
# 63966  Department of Electrical Engineering and Compu...
# 63967  Département de Biologie Faculté des Sciences U...
# 63968  The Forsyth Institute Department of Microbiolo...
#
#                                               University  Start Date  \
# 0                                   Nicht zuteilbar - NA  01.10.1975
# 1                              Université de Genève - GE  01.10.1975
# 2                NPO (Biblioth., Museen, Verwalt.) - NPO  01.03.1976
# 3                                 Universität Basel - BS  01.10.1975
# 4                NPO (Biblioth., Museen, Verwalt.) - NPO  01.01.1976
# 5                            Université de Fribourg - FR  01.01.1976
# 6                            Université de Fribourg - FR  01.01.1976
# 7                                Universität Zürich - ZH  01.10.1975
# 8                            Université de Lausanne - LA  01.10.1975
# 9                              Université de Genève - GE  01.10.1975
# 10                           Université de Fribourg - FR  01.10.1975
# 11               NPO (Biblioth., Museen, Verwalt.) - NPO  01.10.1975
# 12                             Université de Genève - GE  01.10.1975
# 13                                Universität Basel - BS  01.10.1975
# 14                               Universität Zürich - ZH  01.10.1975
# 15                           Université de Fribourg - FR  01.10.1975
# 16                             Université de Genève - GE  01.10.1975
# 17                               Universität Zürich - ZH  01.01.1976
# 18                                  Nicht zuteilbar - NA  01.01.1976
# 19                           Université de Lausanne - LA  01.12.1975
# 20                             Université de Genève - GE  01.10.1975
# 21                                 Universität Bern - BE  01.10.1975
# 22                               Universität Zürich - ZH  01.01.1976
# 23                             Université de Genève - GE  01.10.1975
# 24                                  Nicht zuteilbar - NA  01.01.1976
# 25                                  Nicht zuteilbar - NA  01.10.1975
# 26               NPO (Biblioth., Museen, Verwalt.) - NPO  01.10.1975
# 27               NPO (Biblioth., Museen, Verwalt.) - NPO  01.10.1975
# 28                               Universität Zürich - ZH  01.10.1975
# 29     Eidg. Forschungsanstalt für Wald,Schnee,Land -...  01.10.1975
# ...                                                  ...         ...
# 63939                           Hochschule Luzern - HSLU  01.08.2016
# 63940                                                NaN  01.07.2016
# 63941                                                NaN  01.08.2016
# 63942                                                NaN  01.07.2016
# 63943                                                NaN  01.08.2016
# 63944                                                NaN  01.07.2016
# 63945                                                NaN  01.08.2016
# 63946                                                NaN  01.09.2016
# 63947                                                NaN  01.08.2016
# 63948                                                NaN  01.09.2016
# 63949                                                NaN  01.09.2016
# 63950            NPO (Biblioth., Museen, Verwalt.) - NPO  01.10.2016
# 63951                                  ETH Zürich - ETHZ  01.10.2016
# 63952                Forschungsanstalten Agroscope - AGS  01.10.2016
# 63953                       Firmen/Privatwirtschaft - FP  01.09.2016
# 63954                                                NaN  01.09.2016
# 63955                             Universität Basel - BS  01.10.2016
# 63956                                                NaN  01.08.2016
# 63957                                                NaN  01.08.2016
# 63958                            Universität Zürich - ZH  01.10.2016
# 63959                        Université de Lausanne - LA  01.10.2016
# 63960                                                NaN  01.10.2016
# 63961                                                NaN  01.10.2016
# 63962                                                NaN  01.09.2016
# 63963                 HES de Suisse occidentale - HES-SO  01.10.2016
# 63964             Zürcher Fachhochschule (ohne PH) - ZFH  01.10.2016
# 63965             Zürcher Fachhochschule (ohne PH) - ZFH  01.09.2016
# 63966                                                NaN  01.09.2016
# 63967                                                NaN  01.09.2016
# 63968                                                NaN  01.10.2016
#
#          End Date Approved Amount
# 0      30.09.1976        11619.00
# 1      30.09.1976        41022.00
# 2      28.02.1985        79732.00
# 3      30.09.1976        52627.00
# 4      30.04.1978       120042.00
# 5      31.12.1978        53009.00
# 6      31.12.1976        25403.00
# 7      31.03.1977        47100.00
# 8      31.03.1977        25814.00
# 9      30.09.1978       360000.00
# 10     31.12.1978       153886.00
# 11     30.09.1978       862200.00
# 12     30.09.1977       116991.00
# 13     31.12.1978       112664.00
# 14     31.12.1975         5000.00
# 15     30.09.1977       204018.00
# 16     30.09.1977       149485.00
# 17     31.08.1977        83983.00
# 18     31.12.1976        38152.00
# 19     31.01.1977        14138.00
# 20     30.09.1978       164602.00
# 21     30.04.1978       147795.00
# 22     30.06.1977        24552.00
# 23     30.09.1978        44802.00
# 24     31.12.1979        56000.00
# 25     30.09.1977       152535.00
# 26     30.09.1976       225000.00
# 27     30.04.1978       179124.00
# 28     31.03.1976        20000.00
# 29     30.09.1978       445198.00
# ...           ...             ...
# 63939  31.07.2017         1898.00
# 63940  30.09.2016         9300.00
# 63941  31.10.2016         9500.00
# 63942  31.07.2016         4000.00
# 63943  31.10.2016        11000.00
# 63944  31.08.2016         7500.00
# 63945  30.09.2016         8000.00
# 63946  30.11.2016         9300.00
# 63947  30.09.2016         7000.00
# 63948  31.10.2016         6000.00
# 63949  30.09.2016         4500.00
# 63950  31.12.2016         2800.00
# 63951  30.09.2017        99952.00
# 63952  31.12.2017        98040.00
# 63953  28.02.2018       100000.00
# 63954  30.11.2016        10500.00
# 63955  31.12.2016        10030.00
# 63956  31.10.2016         7870.00
# 63957  31.08.2016         3150.00
# 63958  31.12.2016        10600.00
# 63959  31.12.2016         2515.00
# 63960  31.10.2016         3500.00
# 63961  31.10.2016         4000.00
# 63962  30.09.2016         3550.00
# 63963  31.12.2016         3000.00
# 63964  31.12.2016         1000.00
# 63965  30.11.2016         2000.00
# 63966  31.12.2016        10500.00
# 63967  30.11.2016         9500.00
# 63968  30.11.2016         7000.00
#
# [53059 rows x 7 columns]

# %% [markdown]
# Using only university names as a parametrer for geolocators isn't enough, because we get about half of the results.
# A better idea would be using university name, and if there is no result, using the institution name as a second chance.
# We will then take both universities and institution names into account in order to do our research:
# 1) Create initial data containers :
#     - a key-value (name-canton) dictionary for universities and institutions :
#         -['University', 'Canton'] and ['Institution', 'Canton']
#     - a table that contains all cantons that have been found
# 2) Go trough the dataframe:
#   - Check if the university name exists in our index. If not, geolocate the address
#   - Check if the address is in Switzerland, otherwise canton will be considered as 'None'
#   - If the university address is not found, try to find it with institution name, the same way as above
#   - Extract the canton of the address (if it found an address and if it's in Switzerland). If no canton, let's say 'None' canton
#   - Add the canton name to a the dictionary (or add something like 'None' if no canton has been found), so next university or institution that has been already found won't have to be geolocated again
#   - Add the canton to the canton table
# 3) Add the canton table to the above dataframe in a way that they match with the universities or institutions

# %%
# Let's start by creating our geolocator. We will use Google Maps API :
googlemapsapikeyjson = json.loads(open('google_maps_api_keys.json').read())
# We might need several API keys, to make a potentially huge number of requests
googlemapsapikeys = googlemapsapikeyjson['keys']

# %%
# Specifying the region for the geolocator: for instance, University of Geneva might be localized in the US !
test_geolocator =  geopy.geocoders.GoogleV3(api_key=googlemapsapikeys[0])
test_university_geneva = test_geolocator.geocode("University of Geneva", region='ch')
test_university_geneva
# Out:
# Location(International University in Geneva, Route de Pré-Bois 20, 1215 Meyrin, Switzerland, (46.2243735, 6.1008613, 0.0))

# %% [markdown]
# Now let's start by creating the indexes for universities and institutions :

# %%
try:
    university_canton_dict = json.loads(open('university_canton_dict.json').read())
except FileNotFoundError:
    print('The dictionary for universities has not been saved yet. Let''s create a new dictionary.')
    university_canton_dict = {}
    
try:
    institution_canton_dict = json.loads(open('institution_canton_dict.json').read())
except FileNotFoundError:
    print('The dictionary for institutions has not been saved yet. Let''s create a new dictionary.')
    institution_canton_dict = {}

# %% [markdown]
# We excpect some dirty values if the dataframe, so we are anticipate the problems:

# %%
# We can already add the values in our dataframe that won't lead to an address
university_canton_dict['Nicht zuteilbar - NA'] = {'long_name': 'N/A', 'short_name': 'N/A'} # it means "Not Available" in German !
institution_canton_dict['NaN'] = {'long_name': 'N/A', 'short_name': 'N/A'}
institution_canton_dict['nan'] = {'long_name': 'N/A', 'short_name': 'N/A'}

# %% [markdown]
# We will need to log the next steps in order de debug easily the part of code related to geolocation...
# It seems like it's hard to create a log file in iPython, so we adapted the following of code. Basically, it writes to a file named geolocation.log

# %%
# set root logger level
root_logger = logging.getLogger()
root_logger.setLevel(logging.DEBUG)

# setup custom logger
logger = logging.getLogger(__name__)
handler = logging.FileHandler('geolocation.log')

formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
handler.setFormatter(formatter)
logger.addHandler(handler)

# log
logger.info('This file is used to debug the next code part related to geolocation of universities/institutions')

# %% [markdown]
# It's rather dirty, but we will need more than one API key to make all the requests we need for our data.
# So we created several Google API keys and switch the key each time the current one cannot be used anymore !
# Here is the main code to get all the cantons that we will associate with our dataframe:

# %%
# We create tables that will contains every canton we find, so we'll be able to match it with the dataframe at the end.
logger.debug('Beginning of geolocation : creating canton tables')
canton_shortname_table = [] # eg: VD
canton_longname_table = []# eg: Vaud

# number of rows analysed. Can be limited for debuging (eg : 10) because the number of requests to Google Maps API is limited !
MAX_ROWS = math.inf # values between 0 and math.inf 
row_counter = 0 # will be incremented each time we iterate over a row

# maximum duration of a query to the geocoder, in seconds
geocoder_timeout = 5

# We're going to use more than one API key if we want to make all the requests !! :@
# Keys are referenced in a table, se we start with the first key:
APIkeynumber = 0

# This function definition makes the geolocator "stubborn" : it uses all the keys that are available and if it gets a timeout error, it just tries again !        
def stubborn_geocode(geolocator, address):
    global APIkeynumber
    
    try:
        geolocator = geopy.geocoders.GoogleV3(api_key=googlemapsapikeys[APIkeynumber])
        return geolocator.geocode(address, region='ch', timeout=geocoder_timeout)
    
    except geopy.exc.GeocoderTimedOut:
        print("Error : the geocoder timed out. Let's try again...")
        return stubborn_geocode(geolocator, address)
    
    except geopy.exc.GeocoderQuotaExceeded:
        print("Error : The given key has gone over the requests limit in the 24 hour period or has submitted too many requests in too short a period of time. Let's try again with a different key...")
        APIkeynumber = APIkeynumber + 1
        
        try:
            print("Trying API key n°" + str(APIkeynumber) + "...")           
            return stubborn_geocode(geolocator, address)
        
        except IndexError:
            print("Error : Out of API keys ! We need to request another API key from Google :(")
            print("When you get a new API key, add it to the json file containing the others keys.")
            # We have to stop there... the error will be raised and the execution stopped.
            raise

    
# Go through the dataframe that contains all universities and institutions
for index, row in p3_grant_export_data.iterrows():
    logger.debug("Iterating over row n°" + str(row_counter) + ":")
    # initialize variables that will contain canton name for the current row
    canton_longname = 'N/A'
    canton_shortname = 'N/A'
    # Check if the university name exists in our index
    university_name = row['University']
    institution_name = row['Institution']
    if university_name in university_canton_dict:
        # The university has already been located. Let's add the canton to the canton table
        if university_canton_dict[university_name]['long_name'] is not None:
            logger.debug('University already exists in dictionary (' + university_canton_dict[university_name]['long_name'] + ')')
        else:
            logger.debug('University already exists in dictionary, but no canton is associated to it (it might be outside Switzerland).')
        
        canton_longname = university_canton_dict[university_name]['long_name']
        canton_shortname = university_canton_dict[university_name]['short_name']
    
    elif institution_name in institution_canton_dict:
        # The institution has already ben located, so we add its canton to the canton table
        logger.debug('University wasn''t found, but institution already exists in dictionary (' + institution_canton_dict[institution_name]['long_name'] + ')')
        
        canton_longname = institution_canton_dict[institution_name]['long_name']
        canton_shortname = institution_canton_dict[institution_name]['short_name']
    
    else:
        # Nor the university neither the institution has been found yet, so we have to geolocate it
        logger.debug(str(university_name) + ' / ' + str(institution_name) + ' not found in dictionaries, geolocating...')
        adr = stubborn_geocode(geolocator, university_name)
        if adr is None:
            # No address has been found for this University. So we have to do the same with Institution           
            adr = stubborn_geocode(geolocator, institution_name)
            
        # Now, the address should have been found, either by locating the university or the institution
        if adr is not None:                 
            # Check if it's a Swiss address and finds the right canton
            try:
                swiss_address = False
                for i in adr.raw['address_components']:
                    if i["types"][0] == "country" and i["long_name"] == "Switzerland":
                        # The address is located in Switerland
                        swiss_address = True
                # So, we go on only if we found a Swiss address. Otherwise, there is no point to continue.
                if swiss_address:
                    for i in adr.raw['address_components']:
                        if i["types"][0] == "administrative_area_level_1":
                            # We found a canton !
                            canton_longname = (i['long_name'])
                            canton_shortname = (i['short_name'])                          
                            break
                
                
            
            except IndexError:
                # I don't know where this error comes from exactly, just debugging... it just comes from this line :
                # if i["types"][0] == "country" and i["long_name"] == "Switzerland":
                # For the moment I assume that the the address doesn't match the requirements, so it should not be located in Switzerland
                # Thus, we just forget it and look for the next address.
                print("IndexError : no canton found for the current row")
                
            except KeyError:
                print("KeyError : no canton found for the current row")
                print("Current item: n°" + str(len(canton_shortname_table)))
                # The address doesn't act as excpected. There are two possibilities :
                # - The address doesn't contain the field related to the canton
                # - The address doesn't contain the field related to the country
                # So we don't consider this address as a Swiss one and we give up with this one.
    
    # Let's add what we found about the canton !
    # If we didn't find any canton for the current university/institution, it will just append 'N/A' to the tables.
    logger.debug("Appending canton to the table: " + canton_longname)
    canton_shortname_table.append(canton_shortname)
    canton_longname_table.append(canton_longname)
    
    # We also add it to the university/institution dictionary, in order to limit the number of requests
    university_canton_dict[university_name] = {}
    university_canton_dict[university_name]['short_name'] = canton_shortname
    university_canton_dict[university_name]['long_name'] = canton_longname
    institution_canton_dict[institution_name] = {}
    institution_canton_dict[institution_name]['short_name'] = canton_shortname
    institution_canton_dict[institution_name]['long_name'] = canton_longname
            

    row_counter = row_counter + 1
    if row_counter >= MAX_ROWS:
        print("Maximum number of rows reached ! (" + str(MAX_ROWS) + ")")
        print("Increase the MAX_ROWS variable to analyse more locations")
        print("No limit : MAX_ROWS = maths.inf")
        break

# %%
# We have the table containing all cantons !
len(canton_shortname_table)
# Out:
# 53059

# %%
canton_longname_table
# Out:
# ['N/A',
#  'Genève',
#  'Zurich',
#  'Basel-Stadt',
#  'Zurich',
#  'Fribourg',
#  'Fribourg',
#  'Zürich',
#  'Vaud',
#  'Genève',
#  'Fribourg',
#  'Zurich',
#  'Genève',
#  'Basel-Stadt',
#  'Zürich',
#  'Fribourg',
#  'Genève',
#  'Zürich',
#  'N/A',
#  'Vaud',
#  'Genève',
#  'Canton of Bern',
#  'Zürich',
#  'Genève',
#  'N/A',
#  'N/A',
#  'Zurich',
#  'Zurich',
#  'Zürich',
#  'Vaud',
#  'Zurich',
#  'Zurich',
#  'Basel-Stadt',
#  'Zurich',
#  'Genève',
#  'Zurich',
#  'N/A',
#  'Zurich',
#  'Canton of Neuchâtel',
#  'Genève',
#  'Genève',
#  'N/A',
#  'Fribourg',
#  'Canton of Bern',
#  'Zürich',
#  'Basel-Stadt',
#  'Basel-Stadt',
#  'Zurich',
#  'Basel-Stadt',
#  'Genève',
#  'N/A',
#  'Vaud',
#  'Zurich',
#  'Canton of Neuchâtel',
#  'Zurich',
#  'Genève',
#  'Geneva',
#  'Vaud',
#  'Zurich',
#  'Canton of Bern',
#  'Genève',
#  'Fribourg',
#  'Zurich',
#  'Canton of Neuchâtel',
#  'Canton of Bern',
#  'Zurich',
#  'Zürich',
#  'Fribourg',
#  'Zurich',
#  'Genève',
#  'Genève',
#  'Fribourg',
#  'Zürich',
#  'Zurich',
#  'Zurich',
#  'Zurich',
#  'Zürich',
#  'Zurich',
#  'Geneva',
#  'Canton of Bern',
#  'N/A',
#  'Canton of Bern',
#  'Sankt Gallen',
#  'Canton of Bern',
#  'Canton of Bern',
#  'Zürich',
#  'Zürich',
#  'Zurich',
#  'Sankt Gallen',
#  'Aargau',
#  'Zürich',
#  'Zürich',
#  'Zürich',
#  'Zurich',
#  'Zurich',
#  'Zurich',
#  'Genève',
#  'Zurich',
#  'Genève',
#  'Vaud',
#  'Basel-Stadt',
#  'Zürich',
#  'Canton of Bern',
#  'Zurich',
#  'Basel-Stadt',
#  'Canton of Bern',
#  'Canton of Neuchâtel',
#  'Zurich',
#  'Canton of Bern',
#  'Zurich',
#  'N/A',
#  'Sankt Gallen',
#  'Zürich',
#  'Canton of Bern',
#  'N/A',
#  'Vaud',
#  'N/A',
#  'Zurich',
#  'Canton of Neuchâtel',
#  'Fribourg',
#  'Genève',
#  'Canton of Bern',
#  'Zürich',
#  'N/A',
#  'N/A',
#  'Zurich',
#  'Fribourg',
#  'Canton of Neuchâtel',
#  'Zurich',
#  'Zurich',
#  'N/A',
#  'Fribourg',
#  'Fribourg',
#  'Zurich',
#  'Zurich',
#  'N/A',
#  'Zurich',
#  'Geneva',
#  'Grisons',
#  'Zürich',
#  'Genève',
#  'Basel-Stadt',
#  'Vaud',
#  'Fribourg',
#  'Zurich',
#  'Zurich',
#  'Genève',
#  'Zurich',
#  'Canton of Neuchâtel',
#  'Canton of Bern',
#  'Genève',
#  'Canton of Bern',
#  'Canton of Bern',
#  'Genève',
#  'N/A',
#  'Genève',
#  'Zurich',
#  'Canton of Bern',
#  'Sankt Gallen',
#  'Sankt Gallen',
#  'Geneva',
#  'Genève',
#  'Genève',
#  'Canton of Neuchâtel',
#  'N/A',
#  'Sankt Gallen',
#  'Zurich',
#  'Fribourg',
#  'Genève',
#  'Zurich',
#  'Fribourg',
#  'N/A',
#  'Canton of Bern',
#  'Canton of Bern',
#  'Vaud',
#  'Fribourg',
#  'Canton of Neuchâtel',
#  'Sankt Gallen',
#  'Zurich',
#  'Genève',
#  'N/A',
#  'N/A',
#  'Zurich',
#  'Sankt Gallen',
#  'N/A',
#  'Canton of Neuchâtel',
#  'Zürich',
#  'Genève',
#  'Genève',
#  'Zürich',
#  'Fribourg',
#  'Canton of Bern',
#  'N/A',
#  'Zurich',
#  'Basel-Stadt',
#  'Genève',
#  'Vaud',
#  'Genève',
#  'Fribourg',
#  'Canton of Bern',
#  'Sankt Gallen',
#  'Zürich',
#  'Canton of Bern',
#  'Canton of Bern',
#  'Canton of Bern',
#  'Sankt Gallen',
#  'Zurich',
#  'Zurich',
#  'Sankt Gallen',
#  'Basel-Stadt',
#  'Vaud',
#  'Sankt Gallen',
#  'Genève',
#  'N/A',
#  'Zürich',
#  'Zurich',
#  'Zürich',
#  'Zürich',
#  'Zürich',
#  'Zurich',
#  'Zurich',
#  'Zurich',
#  'Zurich',
#  'Geneva',
#  'N/A',
#  'Basel-Stadt',
#  'Zurich',
#  'Fribourg',
#  'Geneva',
#  'N/A',
#  'Genève',
#  'N/A',
#  'Canton of Bern',
#  'Vaud',
#  'Zurich',
#  'Vaud',
#  'Sankt Gallen',
#  'Zurich',
#  'N/A',
#  'Canton of Neuchâtel',
#  'Zurich',
#  'Zurich',
#  'Canton of Bern',
#  'N/A',
#  'N/A',
#  'N/A',
#  'Zurich',
#  'Fribourg',
#  'Zurich',
#  'N/A',
#  'Vaud',
#  'Zürich',
#  'Zurich',
#  'N/A',
#  'Zurich',
#  'Vaud',
#  'Zurich',
#  'N/A',
#  'Sankt Gallen',
#  'Zürich',
#  'Basel-Stadt',
#  'Zurich',
#  'Sankt Gallen',
#  'Vaud',
#  'N/A',
#  'Fribourg',
#  'Sankt Gallen',
#  'Zurich',
#  'Genève',
#  'Aargau',
#  'Genève',
#  'Basel-Stadt',
#  'Zurich',
#  'N/A',
#  'Genève',
#  'Zürich',
#  'Sankt Gallen',
#  'Zürich',
#  'Genève',
#  'Zürich',
#  'Genève',
#  'Vaud',
#  'Fribourg',
#  'Zurich',
#  'Fribourg',
#  'Zurich',
#  'Zurich',
#  'Fribourg',
#  'Genève',
#  'Vaud',
#  'Zurich',
#  'Genève',
#  'Canton of Bern',
#  'Genève',
#  'N/A',
#  'Zurich',
#  'Fribourg',
#  'Sankt Gallen',
#  'Fribourg',
#  'N/A',
#  'Zürich',
#  'Zürich',
#  'Fribourg',
#  'N/A',
#  'Canton of Bern',
#  'Genève',
#  'Zurich',
#  'N/A',
#  'Genève',
#  'Luzern',
#  'Canton of Bern',
#  'N/A',
#  'Geneva',
#  'Zurich',
#  'Genève',
#  'Zurich',
#  'Zürich',
#  'Zürich',
#  'Zürich',
#  'Geneva',
#  'Zürich',
#  'Zurich',
#  'Basel-Stadt',
#  'Zurich',
#  'Zurich',
#  'Zurich',
#  'Basel-Stadt',
#  'Zürich',
#  'Zurich',
#  'Genève',
#  'Zürich',
#  'Basel-Stadt',
#  'Zurich',
#  'N/A',
#  'Sankt Gallen',
#  'Zurich',
#  'N/A',
#  'Zürich',
#  'Zurich',
#  'N/A',
#  'N/A',
#  'Zurich',
#  'Zurich',
#  'Zurich',
#  'Genève',
#  'Zurich',
#  'Zürich',
#  'Zürich',
#  'Zürich',
#  'Basel-Stadt',
#  'Zurich',
#  'N/A',
#  'Basel-Stadt',
#  'N/A',
#  'Basel-Stadt',
#  'Vaud',
#  'Fribourg',
#  'Canton of Bern',
#  'Canton of Bern',
#  'Zürich',
#  'Vaud',
#  'Zurich',
#  'N/A',
#  'Vaud',
#  'Zürich',
#  'Zurich',
#  'Zurich',
#  'Zurich',
#  'Zurich',
#  'Luzern',
#  'Basel-Stadt',
#  'Fribourg',
#  'Canton of Bern',
#  'Zurich',
#  'Vaud',
#  'Sankt Gallen',
#  'Fribourg',
#  'Genève',
#  'Zurich',
#  'Canton of Bern',
#  'N/A',
#  'N/A',
#  'Fribourg',
#  'Sankt Gallen',
#  'Vaud',
#  'Vaud',
#  'N/A',
#  'Fribourg',
#  'Zürich',
#  'Zurich',
#  'Zürich',
#  'Fribourg',
#  'Zürich',
#  'N/A',
#  'N/A',
#  'Genève',
#  'Fribourg',
#  'Canton of Bern',
#  'Fribourg',
#  'Zürich',
#  'Genève',
#  'Vaud',
#  'Sankt Gallen',
#  'N/A',
#  'Basel-Stadt',
#  'N/A',
#  'Canton of Bern',
#  'Vaud',
#  'Zurich',
#  'Genève',
#  'Zurich',
#  'Genève',
#  'Zurich',
#  'Genève',
#  'Genève',
#  'Fribourg',
#  'Zurich',
#  'Zürich',
#  'Fribourg',
#  'Geneva',
#  'Basel-Stadt',
#  'Geneva',
#  'Canton of Neuchâtel',
#  'Zürich',
#  'Zürich',
#  'Genève',
#  'Fribourg',
#  'Zurich',
#  'Genève',
#  'N/A',
#  'Canton of Bern',
#  'Basel-Stadt',
#  'Zurich',
#  'Canton of Bern',
#  'Canton of Bern',
#  'Genève',
#  'Vaud',
#  'Zurich',
#  'Sankt Gallen',
#  'Zurich',
#  'Vaud',
#  'Genève',
#  'Fribourg',
#  'Vaud',
#  'Zürich',
#  'Aargau',
#  'N/A',
#  'Zurich',
#  'Zurich',
#  'Zurich',
#  'Zurich',
#  'Fribourg',
#  'Zurich',
#  'Zurich',
#  'Canton of Neuchâtel',
#  'Genève',
#  'Fribourg',
#  'Canton of Bern',
#  'Zürich',
#  'N/A',
#  'Geneva',
#  'Basel-Stadt',
#  'Zurich',
#  'Zurich',
#  'Sankt Gallen',
#  'Zürich',
#  'Zürich',
#  'Basel-Stadt',
#  'Canton of Bern',
#  'Zürich',
#  'Zurich',
#  'Genève',
#  'Genève',
#  'Zurich',
#  'Basel-Stadt',
#  'Canton of Bern',
#  'Canton of Bern',
#  'Canton of Bern',
#  'Genève',
#  'Zurich',
#  'N/A',
#  'Zurich',
#  'Zurich',
#  'Sankt Gallen',
#  'N/A',
#  'Genève',
#  'Fribourg',
#  'N/A',
#  'Basel-Stadt',
#  'Genève',
#  'Zurich',
#  'Zurich',
#  'Zürich',
#  'N/A',
#  'Vaud',
#  'Canton of Neuchâtel',
#  'Genève',
#  'Sankt Gallen',
#  'Basel-Stadt',
#  'Zurich',
#  'Canton of Bern',
#  'Vaud',
#  'Zürich',
#  'N/A',
#  'Canton of Neuchâtel',
#  'Genève',
#  'N/A',
#  'N/A',
#  'N/A',
#  'Canton of Neuchâtel',
#  'Zurich',
#  'Canton of Neuchâtel',
#  'Zürich',
#  'Zürich',
#  'Zurich',
#  'Zurich',
#  'Fribourg',
#  'Zürich',
#  'Canton of Bern',
#  'Zürich',
#  'Basel-Stadt',
#  'Zürich',
#  'Zurich',
#  'N/A',
#  'Zürich',
#  'Zürich',
#  'Canton of Bern',
#  'Fribourg',
#  'Zürich',
#  'Zürich',
#  'Genève',
#  'Zurich',
#  'Canton of Bern',
#  'Zurich',
#  'Zurich',
#  'Vaud',
#  'Genève',
#  'Zürich',
#  'N/A',
#  'Zurich',
#  'Fribourg',
#  'Zurich',
#  'Genève',
#  'Zurich',
#  'Zurich',
#  'Fribourg',
#  'Geneva',
#  'Canton of Bern',
#  'Genève',
#  'Basel-Stadt',
#  'N/A',
#  'Zurich',
#  'Genève',
#  'Genève',
#  'Zürich',
#  'Genève',
#  'Canton of Bern',
#  'Basel-Stadt',
#  'Genève',
#  'Sankt Gallen',
#  'Zürich',
#  'Genève',
#  'Fribourg',
#  'Canton of Neuchâtel',
#  'Zurich',
#  'Genève',
#  'Fribourg',
#  'Canton of Bern',
#  'Zürich',
#  'N/A',
#  'Fribourg',
#  'Zurich',
#  'Fribourg',
#  'Zürich',
#  'Zurich',
#  'Grisons',
#  'Fribourg',
#  'Fribourg',
#  'Zurich',
#  'Zurich',
#  'Sankt Gallen',
#  'Canton of Bern',
#  'Zurich',
#  'N/A',
#  'Zurich',
#  'N/A',
#  'N/A',
#  'Canton of Bern',
#  'N/A',
#  'Zurich',
#  'Zürich',
#  'Canton of Neuchâtel',
#  'Basel-Stadt',
#  'Sankt Gallen',
#  'N/A',
#  'Genève',
#  'Canton of Bern',
#  'Zürich',
#  'Genève',
#  'Fribourg',
#  'Genève',
#  'Geneva',
#  'Fribourg',
#  'Sankt Gallen',
#  'Zürich',
#  'Genève',
#  'Canton of Bern',
#  'Vaud',
#  'Basel-Stadt',
#  'N/A',
#  'Zurich',
#  'Basel-Stadt',
#  'Genève',
#  'Zürich',
#  'Genève',
#  'Zürich',
#  'Genève',
#  'Zurich',
#  'Zürich',
#  'Zurich',
#  'Zürich',
#  'Canton of Bern',
#  'Geneva',
#  'Genève',
#  'Sankt Gallen',
#  'Genève',
#  'Zurich',
#  'Basel-Stadt',
#  'Zurich',
#  'N/A',
#  'Zurich',
#  'Zurich',
#  'Vaud',
#  'Zurich',
#  'Zurich',
#  'Zurich',
#  'Zurich',
#  'Zurich',
#  'Zürich',
#  'N/A',
#  'Canton of Neuchâtel',
#  'Genève',
#  'Zurich',
#  'Zurich',
#  'Zurich',
#  'Zurich',
#  'Zurich',
#  'N/A',
#  'Zürich',
#  'Basel-Stadt',
#  'Zurich',
#  'Canton of Neuchâtel',
#  'Zurich',
#  'Zürich',
#  'Zurich',
#  'Sankt Gallen',
#  'N/A',
#  'Zurich',
#  'Genève',
#  'Aargau',
#  'Genève',
#  'Fribourg',
#  'Vaud',
#  'N/A',
#  'Zurich',
#  'Fribourg',
#  'Basel-Stadt',
#  'Zürich',
#  'Zürich',
#  'Vaud',
#  'Zurich',
#  'Canton of Bern',
#  'Canton of Bern',
#  'Genève',
#  'Vaud',
#  'Basel-Stadt',
#  'Genève',
#  'Vaud',
#  'Zürich',
#  'Zürich',
#  'Canton of Bern',
#  'Canton of Neuchâtel',
#  'Zurich',
#  'Vaud',
#  'Genève',
#  'Fribourg',
#  'Zurich',
#  'Genève',
#  'Genève',
#  'Fribourg',
#  'Genève',
#  'N/A',
#  'Fribourg',
#  'N/A',
#  'N/A',
#  'Zurich',
#  'Zurich',
#  'Zurich',
#  'Zurich',
#  'Genève',
#  'Genève',
#  'Zürich',
#  'Sankt Gallen',
#  'Zurich',
#  'Ticino',
#  'Genève',
#  'Aargau',
#  'Canton of Bern',
#  'Zurich',
#  'Vaud',
#  'N/A',
#  'Zürich',
#  'Zürich',
#  'Zurich',
#  'Fribourg',
#  'Zürich',
#  'Zürich',
#  'Zurich',
#  'Basel-Stadt',
#  'Zürich',
#  'Zürich',
#  'Canton of Bern',
#  'Basel-Stadt',
#  'Canton of Bern',
#  'N/A',
#  'N/A',
#  'Vaud',
#  'N/A',
#  'Zürich',
#  'Zurich',
#  'Canton of Bern',
#  'Zurich',
#  'Basel-Stadt',
#  'Zürich',
#  'Genève',
#  'N/A',
#  'Zürich',
#  'Basel-Stadt',
#  'Zurich',
#  'Canton of Bern',
#  'Zurich',
#  'N/A',
#  'Vaud',
#  'Basel-Stadt',
#  'Fribourg',
#  'N/A',
#  'Genève',
#  'Zürich',
#  'Canton of Solothurn',
#  'Genève',
#  'Zurich',
#  'Genève',
#  'Vaud',
#  'Zurich',
#  'Zurich',
#  'N/A',
#  'Zurich',
#  'Zurich',
#  'Canton of Bern',
#  'Zürich',
#  'Canton of Neuchâtel',
#  'Canton of Bern',
#  'Genève',
#  'Basel-Stadt',
#  'N/A',
#  'Zurich',
#  'Zurich',
#  'Fribourg',
#  'Canton of Bern',
#  'Zürich',
#  'Zürich',
#  'N/A',
#  'Fribourg',
#  'Zürich',
#  'Canton of Bern',
#  'Zürich',
#  'N/A',
#  'Genève',
#  'N/A',
#  'Zürich',
#  'Zurich',
#  'Vaud',
#  'Zürich',
#  'Fribourg',
#  'Canton of Neuchâtel',
#  'Zurich',
#  'Zurich',
#  'Fribourg',
#  'Zurich',
#  'Genève',
#  'Canton of Neuchâtel',
#  'Zürich',
#  'Zürich',
#  'Genève',
#  'Zurich',
#  'Vaud',
#  'Genève',
#  'Sankt Gallen',
#  'Genève',
#  'Sankt Gallen',
#  'N/A',
#  'Basel-Stadt',
#  'Zurich',
#  'Genève',
#  'Vaud',
#  'Genève',
#  'Aargau',
#  'Canton of Bern',
#  'Basel-Stadt',
#  'Zurich',
#  'Zürich',
#  'Basel-Stadt',
#  'Genève',
#  'Canton of Bern',
#  'Genève',
#  'N/A',
#  'Canton of Bern',
#  'N/A',
#  'Aargau',
#  'Zürich',
#  'Genève',
#  'Zürich',
#  'Zurich',
#  'Zurich',
#  'Zurich',
#  'Zurich',
#  'Canton of Neuchâtel',
#  'Zürich',
#  'Vaud',
#  'Zurich',
#  'N/A',
#  'N/A',
#  'Vaud',
#  'Canton of Bern',
#  'Zurich',
#  'N/A',
#  'Genève',
#  'Zürich',
#  'Vaud',
#  'Zurich',
#  'Zürich',
#  'Genève',
#  'Zürich',
#  'Genève',
#  'Genève',
#  'Geneva',
#  'Canton of Bern',
#  'Genève',
#  'Vaud',
#  'Genève',
#  'Zurich',
#  'Zürich',
#  'N/A',
#  'N/A',
#  'Genève',
#  'Zurich',
#  'N/A',
#  'Basel-Stadt',
#  'Genève',
#  'Genève',
#  'Basel-Stadt',
#  'N/A',
#  'N/A',
#  'Zurich',
#  'Canton of Bern',
#  'Canton of Bern',
#  'Canton of Bern',
#  'Zürich',
#  'N/A',
#  'Zurich',
#  'Basel-Stadt',
#  'Canton of Neuchâtel',
#  'Zürich',
#  'Zurich',
#  'Sankt Gallen',
#  'Genève',
#  'Fribourg',
#  'Zürich',
#  'Zurich',
#  'Canton of Bern',
#  'Canton of Bern',
#  'Zürich',
#  'Zürich',
#  'Genève',
#  'N/A',
#  'Canton of Bern',
#  'Fribourg',
#  'Zurich',
#  'Canton of Bern',
#  'Fribourg',
#  'Zürich',
#  'Zurich',
#  'N/A',
#  'Zurich',
#  'Zurich',
#  'Vaud',
#  'N/A',
#  'Vaud',
#  'Basel-Stadt',
#  'Canton of Bern',
#  'Zürich',
#  'Canton of Bern',
#  'Vaud',
#  'Zurich',
#  'Genève',
#  'Zurich',
#  'Zürich',
#  'Genève',
#  'Zürich',
#  'Genève',
#  'Vaud',
#  'Zurich',
#  'Sankt Gallen',
#  'Zurich',
#  'N/A',
#  'Vaud',
#  'N/A',
#  'Zurich',
#  'Zurich',
#  'Fribourg',
#  'Zurich',
#  'Zürich',
#  'Zurich',
#  'Vaud',
#  'N/A',
#  'Zurich',
#  'Zürich',
#  'Zurich',
#  'Genève',
#  'Vaud',
#  'Vaud',
#  'N/A',
#  'N/A',
#  'N/A',
#  'Vaud',
#  'Zurich',
#  'Vaud',
#  'Genève',
#  'Vaud',
#  'Canton of Bern',
#  'Zurich',
#  'Genève',
#  'Canton of Bern',
#  'Canton of Bern',
#  'N/A',
#  'N/A',
#  'Canton of Bern',
#  'Canton of Bern',
#  'Fribourg',
#  'Basel-Stadt',
#  'Fribourg',
#  'Zurich',
#  'Zurich',
#  'Zurich',
#  'Zurich',
#  'Zurich',
#  'Genève',
#  'Canton of Bern',
#  'Basel-Stadt',
#  'N/A',
#  'Zurich',
#  'Genève',
#  'Basel-Stadt',
#  'Genève',
#  'Sankt Gallen',
#  'Zurich',
#  'N/A',
#  'Grisons',
#  'Zürich',
#  'Basel-Stadt',
#  'Vaud',
#  'Fribourg',
#  'Vaud',
#  'Zürich',
#  'N/A',
#  'Canton of Bern',
#  'Zürich',
#  'N/A',
#  'Canton of Bern',
#  'Basel-Stadt',
#  'Canton of Bern',
#  'Geneva',
#  'Fribourg',
#  'Zürich',
#  'N/A',
#  'Basel-Stadt',
#  'N/A',
#  'Canton of Neuchâtel',
#  'Zurich',
#  'Basel-Stadt',
#  'Vaud',
#  'N/A',
#  'Genève',
#  'Zurich',
#  'Canton of Bern',
#  'N/A',
#  'Genève',
#  'Vaud',
#  'Genève',
#  'Sankt Gallen',
#  ...]

# %%
# We save the dictionary of cantons associated with universities
# Thus we won't need to make requests that have already been made to Google Maps next time we run this notebook !
with open('university_canton_dict.json', 'w') as fp:
    json.dump(university_canton_dict, fp, indent=4)
university_canton_dict
# Out:
# {nan: {'long_name': 'N/A', 'short_name': 'N/A'},
#  'Università della Svizzera italiana - USI': {'long_name': 'Lucerne',
#   'short_name': 'LU'},
#  'Fachhochschule Kalaidos - FHKD': {'long_name': 'N/A', 'short_name': 'N/A'},
#  'SUP della Svizzera italiana - SUPSI': {'long_name': 'Ticino',
#   'short_name': 'TI'},
#  'Pädagogische Hochschule Luzern - PHLU': {'long_name': 'Lucerne',
#   'short_name': 'LU'},
#  'Fachhochschule Nordwestschweiz (ohne PH) - FHNW': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  'Université de Neuchâtel - NE': {'long_name': 'Canton of Neuchâtel',
#   'short_name': 'NE'},
#  'Pädagogische Hochschule St. Gallen - PHSG': {'long_name': 'St. Gallen',
#   'short_name': 'SG'},
#  'Haute école pédagogique fribourgeoise - HEPFR': {'long_name': 'Canton of Fribourg',
#   'short_name': 'FR'},
#  'Forschungsanstalten Agroscope - AGS': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'Robert Walser-Stiftung Bern - RWS': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Interkant. Hochschule für Heilpädagogik ZH - HfH': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Forschungsinstitut für biologischen Landbau - FIBL': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Universität Bern - BE': {'long_name': 'Canton of Bern', 'short_name': 'BE'},
#  'Pädagogische Hochschule Schwyz - PHSZ': {'long_name': 'Canton of Schwyz',
#   'short_name': 'SZ'},
#  'Kantonsspital St. Gallen - KSPSG': {'long_name': 'St. Gallen',
#   'short_name': 'SG'},
#  'Pädagogische Hochschule Zürich - PHZFH': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Fernfachhochschule Schweiz (Mitglied SUPSI) - FFHS': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Pädagogische Hochschule Bern - PHBern': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'Inst. Suisse de Spéléologie et Karstologie - ISSKA': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Universität Zürich - ZH': {'long_name': 'Zürich', 'short_name': 'ZH'},
#  'EPF Lausanne - EPFL': {'long_name': 'Vaud', 'short_name': 'VD'},
#  'Forschungskommission SAGW': {'long_name': 'N/A', 'short_name': 'N/A'},
#  'Université de Lausanne - LA': {'long_name': 'Vaud', 'short_name': 'VD'},
#  'Pädagogische Hochschule Wallis - PHVS': {'long_name': 'Valais',
#   'short_name': 'VS'},
#  'Friedrich Miescher Institute - FMI': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Facoltà di Teologia di Lugano - FTL': {'long_name': 'Ticino',
#   'short_name': 'TI'},
#  'Universität St. Gallen - SG': {'long_name': 'Sankt Gallen',
#   'short_name': 'SG'},
#  'Allergie- und Asthmaforschung - SIAF': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Pädagogische Hochschule Graubünden - PHGR': {'long_name': 'Grisons',
#   'short_name': 'GR'},
#  'Université de Genève - GE': {'long_name': 'Genève', 'short_name': 'GE'},
#  'Franklin University Switzerland - FUS': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Swiss Institute of Bioinformatics - SIB': {'long_name': 'Geneva',
#   'short_name': 'GE'},
#  'Swiss Center for Electronics and Microtech. - CSEM': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Haute école pédagogique du canton de Vaud - HEPL': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'Weitere Institute - FINST': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'Inst. universit. romand de Santé au Travail - IST': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Pädagogische Hochschule Thurgau - PHTG': {'long_name': 'Thurgau',
#   'short_name': 'TG'},
#  'Eidg. Hochschulinstitut für Berufsbildung - EHB': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Weitere Spitäler - ASPIT': {'long_name': 'Lucerne', 'short_name': 'LU'},
#  'Institut Universitaire Kurt Bösch - IUKB': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  "Centre de rech. sur l'environnement alpin - CREALP": {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Staatsunabh. Theologische Hochschule Basel - STHB': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  'Istituto Svizzero di Roma - ISR': {'long_name': 'N/A', 'short_name': 'N/A'},
#  'Pädagogische Hochschule Nordwestschweiz - PHFHNW': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Idiap Research Institute - IDIAP': {'long_name': 'Valais',
#   'short_name': 'VS'},
#  'Paul Scherrer Institut - PSI': {'long_name': 'Aargau', 'short_name': 'AG'},
#  'Eidg. Material und Prüfungsanstalt - EMPA': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'NPO (Biblioth., Museen, Verwalt.) - NPO': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Institut für Kulturforschung Graubünden - IKG': {'long_name': 'Grisons',
#   'short_name': 'GR'},
#  'Fachhochschule Ostschweiz - FHO': {'long_name': 'St. Gallen',
#   'short_name': 'SG'},
#  'Universität Basel - BS': {'long_name': 'Basel-Stadt', 'short_name': 'BS'},
#  'Schweiz. Hochschule für Logopädie Rorschach - SHLR': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'NaN': {'long_name': 'N/A', 'short_name': 'N/A'},
#  'Berner Fachhochschule - BFH': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'Biotechnologie Institut Thurgau - BITG': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Schweizer Paraplegiker Forschung - SPF': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Instituto Ricerche Solari Locarno - IRSOL': {'long_name': 'Ticino',
#   'short_name': 'TI'},
#  'Inst. de Hautes Etudes Internat. et du Dév - IHEID': {'long_name': 'Geneva',
#   'short_name': 'GE'},
#  'Zürcher Fachhochschule (ohne PH) - ZFH': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'ETH Zürich - ETHZ': {'long_name': 'Zurich', 'short_name': 'ZH'},
#  'Physikal.-Meteorolog. Observatorium Davos - PMOD': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Eidg. Anstalt für Wasserversorgung - EAWAG': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Schweiz. Institut für Kunstwissenschaft - SIK-ISEA': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'Pädag. Hochschule Tessin (Teilschule SUPSI) - ASP': {'long_name': 'Ticino',
#   'short_name': 'TI'},
#  'AO Research Institute - AORI': {'long_name': 'N/A', 'short_name': 'N/A'},
#  'Haute école pédagogique BE, JU, NE - HEPBEJUNE': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Schweizer Kompetenzzentrum Sozialwissensch. - FORS': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'Pädagogische Hochschule Schaffhausen - PHSH': {'long_name': 'Canton of Schaffhausen',
#   'short_name': 'SH'},
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land - WSL': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'Université de Fribourg - FR': {'long_name': 'Fribourg', 'short_name': 'FR'},
#  'HES de Suisse occidentale - HES-SO': {'long_name': 'Canton of Solothurn',
#   'short_name': 'SO'},
#  'Nicht zuteilbar - NA': {'long_name': 'N/A', 'short_name': 'N/A'},
#  'Forschungsinstitut für Opthalmologie - IRO': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Pädagogische Hochschule Zug - PHZG': {'long_name': 'Canton of Zug',
#   'short_name': 'ZG'},
#  'Ente Ospedaliero Cantonale - EOC': {'long_name': 'Ticino',
#   'short_name': 'TI'},
#  'Universität Luzern - LU': {'long_name': 'Luzern', 'short_name': 'LU'},
#  'Firmen/Privatwirtschaft - FP': {'long_name': 'Aargau', 'short_name': 'AG'},
#  'Hochschule Luzern - HSLU': {'long_name': 'Lucerne', 'short_name': 'LU'}}

# %%
# We save the dictionary of cantons/institutions as well
with open('institution_canton_dict.json', 'w') as fp:
    json.dump(institution_canton_dict, fp, indent=4)
institution_canton_dict
# Out:
# {'UNI: Universität Zürich Institut für Informa tik  Zürich CH': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  nan: {'long_name': 'N/A', 'short_name': 'N/A'},
#  'Universität Luzern': {'long_name': 'Luzern', 'short_name': 'LU'},
#  'Section de Médecine dentaire Physiopathologie orale et Para- dontie': {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'Labor für Perzeption und Okulomotorik Universitätsklinik für Neurologie Inselspital, Universität Bern': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'Departement Musik Zürcher Hochschule der Künste Zürcher Fachhochschule': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Universität Bern Zentrum für universitäre Weiterbildung': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'Abteilung Biochemie Biozentrum Universität Basel': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  "Département d'Histoire de l'Eglise Faculté de Théologie Université de Fribourg": {'long_name': 'Fribourg',
#   'short_name': 'FR'},
#  'Loma Linda University Medical Center': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'Laboratoire de biologie computationnelle et bioinformatique EPFL - IC - IIF - LCBB': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'Hochschule für Musik und Theater Hochschule der Künste Bern': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'Inst. für Sozial- und Präventivmedizin (AGF) Universität Bern': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'Universitäre Psychiatrische Kliniken Universität Basel': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  'Seminar für Kulturwissenschaften und Wissenschaftsforschung Universität Luzern': {'long_name': 'Luzern',
#   'short_name': 'LU'},
#  'NCCR North-South Universität Bern': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'Professur Bauphysik Institut für Technologie in der Architektur ETH Zürich': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'BAK Konjunkturforschung Basel AG': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Centre Suisse de Cartographie de la Faune & Koordinationsstelle für Amphibien- und Reptilienschutz in der Schweiz': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'Cognitive and Decision Sciences Fakultät für Psychologie Universität Basel': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  'Département de linguistique Faculté des Lettres Université de Genève': {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'EAWAG Systems Analysis, Integrated Ass. & modeling': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Unité des Sciences du Mouvement et du sport Département de Médecine Université de Fribourg': {'long_name': 'Fribourg',
#   'short_name': 'FR'},
#  'Zentrum Pol. Bildung und Geschichtsdidaktik Pädagogische Hochschule Fachhochschule Nordwestschweiz': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  'Institute of Computational Physics Zürcher Hochschule für Angewandte Wissenschaften': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  "Geneva Emotion Research Group Faculté Psych. et des Sciences de l'Educat. Univ. de Genève": {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'Zentrum für Abhängigkeitserkrankungen Psychiatrische Universitätsklinik Zürich': {'long_name': 'Zürich',
#   'short_name': 'ZH'},
#  'Abteilung Ökologie und Evolution Departement für Biologie Universität Freiburg': {'long_name': 'Fribourg',
#   'short_name': 'FR'},
#  'Lehrstuhl International Trade and Finance Institut für empirische Wirtschaftsforschung Universität Zürich': {'long_name': 'Zürich',
#   'short_name': 'ZH'},
#  'Bibliothek Kantonsschule Luzern': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Liceo Cantonale Locarno': {'long_name': 'Zurich', 'short_name': 'ZH'},
#  'Universitätsklinik für Pneumologie Inselspital': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  "Laboratoire d'Ophthalmologie expérimentale /Département de Physiologie / CMU": {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'Catholic University of Bukavu': {'long_name': 'N/A', 'short_name': 'N/A'},
#  'Frauenklinik Universitaetsspital Bern': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'Institut für Hausarztmediz Universität Basel': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  'UNI: KLTE Kisérleti fizikai Tanszék  Debrece n H': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Informationsstelle des Zürcher Sozialwesens': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Chronobiologie und Schlafforschung Institut für Pharmakologie und Toxikologie Universität Zürich': {'long_name': 'Zürich',
#   'short_name': 'ZH'},
#  'St. Galler Wirtschafts-Consulting (SWC) Schmid, Widmer, Prey AG': {'long_name': 'Aargau',
#   'short_name': 'AG'},
#  "Fondation Hardt pour l'étude de l'Antiquité classique": {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Volkswirtschaftliche Abteilung Hochschule St. Gallen': {'long_name': 'Sankt Gallen',
#   'short_name': 'SG'},
#  'Groupe de Géomagnétisme Université de Neuchâtel': {'long_name': 'Canton of Neuchâtel',
#   'short_name': 'NE'},
#  'Psychiatrische Universitäts- Poliklinik Zweigstelle': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  'Département de Psychiatrie Faculté de Médecine Université de Genève': {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'Dermatologische Klinik Universitätsspital Zürich': {'long_name': 'Zürich',
#   'short_name': 'ZH'},
#  'UNI: Université de Genève Department of Cond ensed Matter Physics  Genève CH': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'UBC Inversion Facility Earth and Ocean Sciences University of British Columbia': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Département de langues et littéra- tures méditerranéennes (MESLO) Université de Genève': {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'UNI: Université de Lausanne Institut de Géol ogie et Pathologie  1015 Lausanne CH': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Schwabe u. Co. AG': {'long_name': 'Aargau', 'short_name': 'AG'},
#  'Holliger Simonius & Partner Advokatur und Notariat': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  'UNI: Université de Neuchâtel Institut de Phy sique  Neuchâtel CH': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Chemisches Zentrallabor der Uni- versitätskliniken/Abt. für Protein- diagnostik und auswärtige Analysen': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'Kriminologisches Institut Universität Zürich': {'long_name': 'Zürich',
#   'short_name': 'ZH'},
#  'Institut für öffentliches Recht Universität Bern': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'Departement Forschung Klinik für Infektiologie Universitätsspital Basel': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  'Ion Beam Physics PSI and ETH': {'long_name': 'Zurich', 'short_name': 'ZH'},
#  'Division de Biochimie clinique et de Diabétologie expérimentale CMU': {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'Verein NGL-SAA Neue Galerie Luzern - Swiss Academic Association': {'long_name': 'Lucerne',
#   'short_name': 'LU'},
#  'Institut für Infektionskrankheiten Universität Bern': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'Microsens S.A.': {'long_name': 'Aargau', 'short_name': 'AG'},
#  "Ecole Suisse d'archéologie en Grèce  Univ. de Lausanne": {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'FNP Sottostazione Sud delle Alpi': {'long_name': 'Vaud', 'short_name': 'VD'},
#  'Spital Erlenbach': {'long_name': 'Canton of Bern', 'short_name': 'BE'},
#  'Aegyptologisches Seminar der Universität Basel': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  'UNI: Institut suisses de rech. sur le cancer Epalinges CH': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  "Laboratoire d'ophtalmologie éxperimentale Centre Médical Universitaire": {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'UNI: Astronomical Observatory Chinese Academ y of Sciences  Beijing VRC': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Institut für Biomechanik M. E. Müller-Forschungszentrum Universität Bern': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'Università degli Studi di Firenze': {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'UNI: Harward University Graduate School of E ducation Roy E. Larsen Hall,Appian Way Cambr idge Massachusetts 02138 USA': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Laboratoire de systèmes photoniques appliqués EPFL - STI - IMT - LAPD': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'Vögele Kultur Zentrum': {'long_name': 'N/A', 'short_name': 'N/A'},
#  'Department of Computer Engineering Sejong University': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Institut für Humangenetik Universitätsklinikum Leipzig': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'Institut für klinische Epidemiologie Universitätsspital Basel': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  'Allgemeine Psychologie, Kognition Psychologisches Institut Universität Zürich': {'long_name': 'Zürich',
#   'short_name': 'ZH'},
#  'Institut Laue-Langevin': {'long_name': 'N/A', 'short_name': 'N/A'},
#  'Institut für Geschichte Universität Bremen': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  'Zoologisches Institut Universität Freiburg': {'long_name': 'Fribourg',
#   'short_name': 'FR'},
#  'Institut de Chimie biologique': {'long_name': 'Genève', 'short_name': 'GE'},
#  'Laboratoire de systèmes périphériques EPFL - IC - ISIM - LSP': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'UniversitätsSpital Zürich Molekulare Innere Medizin Medpol, DIM': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Institut Interfacultaire de l’Europe Centrale et Orientale Université de Fribourg': {'long_name': 'Fribourg',
#   'short_name': 'FR'},
#  'Hochschule für Gestaltung, Kunst und Konservierung': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  "Institut d'études politiques, historiques et internationales (IEPHI) - Faculté des SSP Université de Lausanne": {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'Swiss Institute of Bioinformatics': {'long_name': 'Geneva',
#   'short_name': 'GE'},
#  'Schweiz. Pastoralsoziologisches Inst. (SPI)': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'Max-Planck-Institut für Pflanzenzüchtungsforschung': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'Redaktion des Schweizerdeutschen Wörterbuchs': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Abteilung Schul- und Unterrichtsforschung Institut für Erziehungswissenschaft Universität Bern': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'Institute of Engineering Mechanics and Systems University of Tsukuba': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Clinique de Chirurgie thoracique Hôpital Cantonal': {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'Institut de Zoologie Département Eco-Ethologie Université de Neuchâtel': {'long_name': 'Canton of Neuchâtel',
#   'short_name': 'NE'},
#  'Denkmalpflege und Archäologie des Kantons Luzern': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Klinik und Poliklinik für Kinderheilkunde Medizinische Universitäts-Kinderklinik Inselspital': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'Institut für Finanzwissenschaft und Finanzrecht': {'long_name': 'Sankt Gallen',
#   'short_name': 'SG'},
#  'Departement für Zeitgeschichte Universität Freiburg': {'long_name': 'Fribourg',
#   'short_name': 'FR'},
#  'Neurochirurgische Intensivstation Neurochirurgische Klinik Universitätsspital Zürich': {'long_name': 'Zürich',
#   'short_name': 'ZH'},
#  'Institut für Organische Chemie Universität Zürich': {'long_name': 'Zürich',
#   'short_name': 'ZH'},
#  'Labor für Thermohydraulik Paul Scherrer Institut': {'long_name': 'Aargau',
#   'short_name': 'AG'},
#  'Vindonissa Museum': {'long_name': 'Zurich', 'short_name': 'ZH'},
#  'Filière ESTS - Travail social HES-SO Valais/Wallis': {'long_name': 'Canton of Solothurn',
#   'short_name': 'SO'},
#  'Institut für Biomedizinische Technik Universität und ETH Zürich': {'long_name': 'Zürich',
#   'short_name': 'ZH'},
#  'Institut des sciences et ingénierie chimiques EPFL - SB - ISIC': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'ETH Zurich Institute for Building Materials Wood Materials Science Lab': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Institut Sekundarstufe II und Pädagogik Pädagogische Hochschule Fachhochschule Nordwestschweiz': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Hochschule Technik+Architektur Luzern': {'long_name': 'Lucerne',
#   'short_name': 'LU'},
#  'Frauenklinik Kantonsspital': {'long_name': 'Lucerne', 'short_name': 'LU'},
#  'EPFL-CDM-MTE': {'long_name': 'Vaud', 'short_name': 'VD'},
#  'Universitäre Psychiatrische Klinken Basel Zentrum Spezielle Psychotherapie ZSP': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  'Schweizerische Kommission "Mittellateinisches Wörterbuch"': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Università della Svizzera Italiana': {'long_name': 'Lucerne',
#   'short_name': 'LU'},
#  'Archivio del Moderno Accademia di architettura USI': {'long_name': 'Lucerne',
#   'short_name': 'LU'},
#  'Kantonsschule Schlossfeld': {'long_name': 'Zurich', 'short_name': 'ZH'},
#  "Clinique d'Urologie Hôpital Cantonal Universitaire": {'long_name': 'Genève',
#   'short_name': 'GE'},
#  "UNI: Fondation Hardt pour l'étude de l'Antiq uité classique  Vandoeuvres CH": {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'UNI: Cranfield University School of Manageme nt  Bedford GB': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Verein "Schweizerische Juristische Datenbank"': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Lab. de Génie Chimique et Biologique Section de Chimie / ISP - LGCB EPFL': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  "Laboratoire d'architecture de processeurs EPFL - IC - ISIM - LAP": {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'Recherche et Développement Institut Fédéral des hautes études en Formation Professionnelle (IFFP)': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Section des HEC': {'long_name': 'Genève', 'short_name': 'GE'},
#  'Institut für Integrative Biologie ETH Zürich + EAWAG': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'UNI: Lawrence Berkeley Laboratories   USA': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Division of Cognitive Neuroscience Institut für Psychologie Universität Basel': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  'Fraueninformationszentrum für Frauen aus Afrika, Asien und Lateinamerika': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  "Service d'Anesthésiologie CHUV": {'long_name': 'Vaud', 'short_name': 'VD'},
#  'Linguatg e cultura rumantscha Universitad da Fribourg': {'long_name': 'Fribourg',
#   'short_name': 'FR'},
#  'Arbeitsgemeinschaft Hafner/Trepp': {'long_name': 'Aargau',
#   'short_name': 'AG'},
#  'Abteilung für Urologie Klinik Hirslanden': {'long_name': 'Zürich',
#   'short_name': 'ZH'},
#  'Curia Vescovile': {'long_name': 'Zurich', 'short_name': 'ZH'},
#  'Laboratoire de Bioénergétique Dépt. de Botanique et Biologie Végétale Université de Genève': {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'Gesundheitsdirektion des Kantons Zürich': {'long_name': 'Sankt Gallen',
#   'short_name': 'SG'},
#  "Chaire d'optimisation discrète EPFL - SB - MATHAA - DISOPT": {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'Geriatrische Universitätsklinik Kantonsspital Basel': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  'Lab. de chimie analytique pharmaceutique (LCAP) Université de Genève': {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'Département de médecine interne Service de médecine interne B CHUV': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'Institut für Parasitologie Vetsuisse-Fakultät Universität Zürich': {'long_name': 'Zürich',
#   'short_name': 'ZH'},
#  'Section de français et de littérature comparée Université de Lausanne': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'ViaStoria - Zentrum für Verkehrsgeschichte Kulturwege Schweiz': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Interdisziplinäres Zentrum für Schlafmedizin Universitäts-Kinderkliniken': {'long_name': 'Zürich',
#   'short_name': 'ZH'},
#  "Centre interfacultaire en droits de l'enfant  Université de Genève": {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'MEDICOAT AG': {'long_name': 'Aargau', 'short_name': 'AG'},
#  'Abteilung für Infektiologie Institut für klinische Epidemiologie Universitätsspital Basel': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  'Faculté des sciences économiques et sociales, Décanat Université de Genève': {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'Zentrum für Forschung und Entwicklung Pädagogische Hochschule Bern': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'Architekturbüro Roth Ueli Architekt ETH/SIA': {'long_name': 'Aargau',
#   'short_name': 'AG'},
#  'Allgemeine und Entwicklungspsychologie Psychologisches Institut Universität Zürich': {'long_name': 'Zürich',
#   'short_name': 'ZH'},
#  'Fachgruppe Moderne Materialien und Medien Fachbereich Konservierung und Restaurierung Hochschule der Künste Bern': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'Université de Genève': {'long_name': 'Genève', 'short_name': 'GE'},
#  'Wirtschaft Gesundheit und Soziales Berner Fachhochschule Gesundheit': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  "Division d'Informatique Hôpital Cantonal Universitaire": {'long_name': 'Genève',
#   'short_name': 'GE'},
#  "Inst. de Géomatique & d'Analyse du Risque Fac. des Géosciences & de l'Environnement Université de Lausanne": {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'Abteilung für medizinische Strahlenphysik Inselspital': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'Dept. Klinisch-Biologische Wissenschaften Universität Basel': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  'Höhere Fachschule für Sozialarbeit und Sozialpädagogik HFS Ostschweiz': {'long_name': 'St. Gallen',
#   'short_name': 'SG'},
#  'Institut Suisse de Bioinformatique Centre Médical Universitaire Université de Genève': {'long_name': 'Geneva',
#   'short_name': 'GE'},
#  'Laboratoire de robotique reconfigurable EPFL - STI - IGM - RRL': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'Gerontopsychiatrisches Zentrum Hegibach Psychiatrische Universitätsklinik Zürich': {'long_name': 'Zürich',
#   'short_name': 'ZH'},
#  'Institut für Unternehmensrecht Universität Luzern': {'long_name': 'Luzern',
#   'short_name': 'LU'},
#  'Abteilung Anatomie Departement für Medizin Universität Freiburg': {'long_name': 'Fribourg',
#   'short_name': 'FR'},
#  'Laboratoire de chimie et biochimie computationnelles EPFL - SB -  ISIC - LCBC': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  "Laboratoire de mécanique des fluides de l'environnement EPFL - ENAC - IIE - EFLUM": {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'Abteilung für Sport- und Leistungs- medizin, Medizinische Klinik & Poli klinik, Ruprecht-Karls-Universität': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Hôpital de Gériatrie': {'long_name': 'Genève', 'short_name': 'GE'},
#  'UNI: Research Center of Molecular Diagnostic s and Therapy Department of Biosensors Mosco w RUS': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'Eidg. Materialprüfungs- und Forschungsanstalt (EMPA)': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'Universität Bern': {'long_name': 'Canton of Bern', 'short_name': 'BE'},
#  'Klinik für Ohren-, Nasen-, Hals- und Gesichtschirurgie Universitätsspital Zürich': {'long_name': 'Zürich',
#   'short_name': 'ZH'},
#  'Institut de Philosophie Faculté des Lettres et Sciences Humaines Université de Neuchâtel': {'long_name': 'Canton of Neuchâtel',
#   'short_name': 'NE'},
#  'M.E. Müller-Inst. Mikroskop & Strukturbiol. Biozentrum Universität Basel': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  'Département de Mathématiques Université de Fribourg': {'long_name': 'Fribourg',
#   'short_name': 'FR'},
#  'Staatsarchiv Uri': {'long_name': 'Zurich', 'short_name': 'ZH'},
#  'Service de Médecine Interne Département de Médecine CHUV': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'Kunsthistorisches Seminar Universität Basel': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  'Klassische Archäologie Departement Altertumswissenschaft Universität Basel': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  'Rapp AG Ingenieure + Planer': {'long_name': 'Aargau', 'short_name': 'AG'},
#  'Klinische Ethik Support & Begleitforschung Clinical Ethics Support & Accompanying': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  'University of Basel Biozentrum Genome Scale Biology & Bioinformatics': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  'Chair of Neurosciences Brain Research Institute University of Zurich': {'long_name': 'Zürich',
#   'short_name': 'ZH'},
#  'UNI: Albert-Ludwigs-Universität Institut für Biologie II/Biochemie  Freiburg D': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Institut für Wirtschafts- und Sozialgeschichte Georg-August-Universität': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Klinik für Radio-Onkologie UniversitätsSpital Zürich': {'long_name': 'Zürich',
#   'short_name': 'ZH'},
#  'UNI: Ustav pro soudobé dejiny CSAV  Prag CSS R': {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'Service de Chirurgie Viscérale Département de Chirurgie Hôpitaux Universitaires de Genève': {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'Département de droit international public et organisation internationale Université de Genève': {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'Societa Retorumantscha Dicziunari Rumantsch Grischun': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  "Université de Genève Bd du Pont d'Arve 40": {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'Klinik und Poliklinik für Dermatologie Inselspital': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'UNI Dufour': {'long_name': 'Genève', 'short_name': 'GE'},
#  "Section d'italien Faculté des lettres Université de Lausanne": {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'Department of Biology and Genetics Ivano-Frankivsk State Medical Academy': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'WSL': {'long_name': 'Vaud', 'short_name': 'VD'},
#  'Forschungsinstitut für die Biologie landwirtschaftlicher Nutztiere (FBN) Oskar Kellner Institut': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'UNI: EPFL Département des Matériaux Laborato ire de Technologie Lausanne CH': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'UNI: Res. Institute for Physics   Budapest H': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'Molekulare Gesundheitswissenschaften Departement Biologie ETH Zürich': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Ausstellungen Zoologisches Museum der Universität Zürich': {'long_name': 'Zürich',
#   'short_name': 'ZH'},
#  'Augenklinik Universitätsspital Zürich': {'long_name': 'Zürich',
#   'short_name': 'ZH'},
#  'mySNF, fiktive Instituts-Adresse (Nicht verwenden) Abteilung IT': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'UNI: University of Calgary Faculty of Manage ment  Calgary CDN': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Département des sciences sociales Université de Fribourg': {'long_name': 'Fribourg',
#   'short_name': 'FR'},
#  'Institut für Europa- und Wirtschaftsvölkerrecht Universität Bern': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'Hôpital cantonal universitaire Unité de Diabétologie Clinique Département de médecine': {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'Wessenbergkommission': {'long_name': 'Zurich', 'short_name': 'ZH'},
#  'Institut de Microtechnique EPFL - STI - IMT': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'Bibliotheque militaire fédérale': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'UNI: University of Birmingham School of Geog raphy Service Sector Research Unit Brimingha m GB': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'MeteoSuisse': {'long_name': 'Zurich', 'short_name': 'ZH'},
#  'Haute Ecole Pédagogique': {'long_name': 'Canton of Fribourg',
#   'short_name': 'FR'},
#  'Pflanzenernährung Institut  für Agrarwissenschaften ETH Zürich': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Institute for Biomedical Ethics University of Basel': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  'EPFL SV BMI LNC': {'long_name': 'Vaud', 'short_name': 'VD'},
#  'Fakultät III für Rechtswissenschaft der Universität Luzern': {'long_name': 'Luzern',
#   'short_name': 'LU'},
#  'Ecole de soin infirmiers "Le Bon Secours"': {'long_name': 'Canton of Solothurn',
#   'short_name': 'SO'},
#  'UNI: State University of Moscow Institute of Zoology and General Ecology Moscow RUS': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  'Laboratoire de traitement des signaux 5 EPFL - STI - IEL - LTS5': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'Abt. Landschaftsdynamik und Raumentwicklung Eidg. Forschungsanstalt WSL': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'Département de Biologie moléculaire des plantes Université de Lausanne': {'long_name': 'Zürich',
#   'short_name': 'ZH'},
#  'Institut für Oberflächentechnik ETH Zürich': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Fachhochschule beider Basel Institut für Umwelttechnologie': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  'Serv. de dermatologie et vénéréologie Dépt. Neurosciences cliniques et dermatol. Hôpital Cantonal de Genève': {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'Geneva University Hospital': {'long_name': 'Genève', 'short_name': 'GE'},
#  'Division de Neuropsychiatrie HUG Belle-Idée': {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'UNI: University of Birmingham Department of Economics  Birmingham GB': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Laboratoire de construction en béton EPFL - ENAC - IIC - IBETON': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'Centre de recherche en physique des plasmas Paul Scherrer Institut': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'University of California Center for Studies in Higher Education International & Area Studies': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Veterinär-Pharmakologisches Institut Vetsuisse-Fakultät Universität Bern': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'Service de génétique médicale CHUV': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'Département de Psychiatrie Université de Genève': {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'Laboratoire de chimie physique moléculaire EPFL - SB - ISIC - LCPM': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'Historisches Seminar Universität Zürich': {'long_name': 'Zürich',
#   'short_name': 'ZH'},
#  'Schweiz. Evang. Kirchenbund SEK Bibliothek': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'Netzwerk Stadt und Landschaft der ETH Zürich (NSL)': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Département de science politique et relations internationales Université de Genève': {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'Institut für Prähistorische und Naturwissen- schaftliche Archäologie Universität Basel': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  'Abteilung für Klinische Neurophysiologie Neurologische Universitätsklinik Kantonsspital Basel': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  'Unité de Thyroïde Hôpital Cantonal Universitaire': {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'Section des Hautes Études Commerciales HEC-FSES Université de Genève': {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'UNI: Friedrich Miescher-Institut  Basel CH': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Commission nationale pour la publication des DDS': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'BAM, Bundesanstalt für Materialforschung und -prüfung': {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'Laboratoire de thérapeutique expérimentale, LABTEX / CMU Division de Pharmacologie Clinique': {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'Präsident der Schweizerischen Stiftung für das Stockalperschloss': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Division de Pneumologie Département de Médecine CHUV': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'Veterinärmedizinische Fakultät Klinik für Andrologie und Gynäkologie Universität Zürich': {'long_name': 'Zürich',
#   'short_name': 'ZH'},
#  'EPFL SV IBI1-GE': {'long_name': 'Vaud', 'short_name': 'VD'},
#  'UNI: Universität Tbilisi Institut für altgeo rgische Sprache und Literatur Tbilisi RUS': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'Schweizerische Musikforschende Gesellschaft': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Deutsches Krebsforschungszentrum': {'long_name': 'Vaud', 'short_name': 'VD'},
#  'Istituto di Ricerca in Biomedicina (IRB)': {'long_name': 'Lucerne',
#   'short_name': 'LU'},
#  'Département de Biologie Cellulaire Faculté des Sciences Université de Genève': {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'Architektur und Bauprozess Institut für Technologie in der Architektur ETH Zürich': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Département de gynécologie et obstétrique Centre hospitalier universitaire vaudois': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  "Parc et Musée d'Archéologie de Neuchâtel et Institut de Préhistoire et des sciences de l'Antiquité": {'long_name': 'Canton of Neuchâtel',
#   'short_name': 'NE'},
#  'Institute for Particle Physics ETH Hönggerberg': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Zentrum für Gender Research u. Früherkennung Universitäre Psychiatrische Kliniken Basel Universitätsspital Basel': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  'Clinique de Chirurgie Pédiatrique Hôpital des Enfants HUG': {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'UNI: University of London Institute of Neuro logy  London GB': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Département de Neurosciences Cliniques Hôpitaux Universitaires de Genève': {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'Institut für Klassische Philologie Universität Bern': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'Département de Français Faculté des lettres Université de Fribourg': {'long_name': 'Fribourg',
#   'short_name': 'FR'},
#  'Service de la recherche Haute école Pédagogique Fribourg': {'long_name': 'Canton of Fribourg',
#   'short_name': 'FR'},
#  'Département de linguistique générale et linguistique française Uni-Bastions': {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'Laboratoire de constructions hydrauliques EPFL - ENAC - IIC - LCH': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'Fachhochschule Nordwestschweiz Hochschule für Technik': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  'Domaine Sociologie et Médias Département des Sciences de la Société Université de Fribourg': {'long_name': 'Fribourg',
#   'short_name': 'FR'},
#  'Laboratoire de Neurosciences Cognitives Brain Mind Institute Faculté des sciences de la vie': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'University Alberta': {'long_name': 'N/A', 'short_name': 'N/A'},
#  'UNI: University of British Columb. Dept of C hemistry  Vancouver CDN': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Max Planck Institute for Chemical Ecology Beutenberg Campus': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Swiss Federal Institute of TechnologyLausann Instit. of Chemical Sciences and Engineering EPFL SB ISIC LCS': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'Schola Cantorum Basiliensis Musik Akademie Basel FHNW': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  'Laboratoire de biophotonique fondamentale EPFL - STI - IBI-STI - LBP': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'Section de langue et littérature françaises Faculté des lettres Université de Genève': {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'Departamento de Matematicas Estadistica y Computacion/ Facultad de Ciencias/ Univers. de Cantabria': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  "Dépt d'Histoire de l'art & de Musicologie Faculté des Lettres Université de Fribourg": {'long_name': 'Fribourg',
#   'short_name': 'FR'},
#  'Abteilung für Infektiologie Universitätsspital Basel': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  'UNI: ETH-Zürich Institut für Pflanzenwissens chaften  Zürich CH': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Institut für Biomechanik D-HEST ETH Zürich': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Institut für Psychologie Lehrstuhl für Biolog. und Diff. Psychologie Albert-Ludwigs-Universität Freiburg': {'long_name': 'Zürich',
#   'short_name': 'ZH'},
#  'Department of Historical Studies University of Cape Town': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Centre interdisciplinaire de microscopie électronique EPFL - SB - CIME': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'Laboratoire de cryptologie algorithmique EPFL - IC - IIF - LACAL': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'Interdisziplinäres Institut für Ethik und Menschenrechte Universität Freiburg': {'long_name': 'Fribourg',
#   'short_name': 'FR'},
#  'UNI: Universität Zürich Institut für Pflanze nbiologie  Zürich CH': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'UNI: National Museum of Wales Department of Geology  Cardiff GB': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Fachbereich Psychologie Philipps-Universität Marburg': {'long_name': 'Zürich',
#   'short_name': 'ZH'},
#  'Forschungsstelle für schweizerische Sozial- und Wirtschaftsgeschichte Universität Zürich': {'long_name': 'Zürich',
#   'short_name': 'ZH'},
#  'Abteilung Geistes- und Sozialwissenschaften / Abt. XII ETH - Zentrum': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Faculté des Sciences Sociales et Politiques Université de Lausanne': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'Département Universitaire de Médecine et Santé Communautaires (DUMSC) CHUV': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'Neurologische Klinik Universitätsspital Zürich': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'UNI: Universität Zürich Paläontologisches In stitut  Zürich CH': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Archäologischer Dienst des Kantons Bern': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Chaire de théorie de la matière condensée EPFL - SB - ITP - CTMC': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'Social and Affective Neuroscience Fakultät für Psychologie Universität Basel': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  'UNI: University of Catania Dept of Procedura l Law  Catania I': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Augenklinik Universitätsspital Basel': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  'Abteilung Zellbiologie Biozentrum Universität Basel': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  'Institute of Metal Physics Russian Academy of Science': {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'Abteilung Funktionspolymere EMPA': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'Sukkulentensammlung Zürich': {'long_name': 'Zurich', 'short_name': 'ZH'},
#  'Institut für Molekulare Systembiologie Departement Health Sciences and Technology ETH Zürich': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Ecole de langue et de civilisation française Faculté des Lettres Université de Genève': {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'Universitätsklinik für viszerale Medizin Inselspital Bern': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'Institut für Chemie und Biologische Chemie Zürcher Hochschule für Angewandte Wissenschaften': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Psychiatriezentrum Rheinau Klinik für psychiatrische Rehabilitation': {'long_name': 'Zürich',
#   'short_name': 'ZH'},
#  'Bundesamt für Umwelt BAFU': {'long_name': 'Zurich', 'short_name': 'ZH'},
#  'EPFL EC-L Expert-Center pour la conservation du patrimoine bâti': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'Departement Umweltsystemwissenschaften ETH Zürich IBP / D-USYS': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Chaire de droit privé et droit romain Département de droit privé Université de Fribourg': {'long_name': 'Fribourg',
#   'short_name': 'FR'},
#  'Abteilung Neuroimmunologie Klinik für Neurologie Universitätsspital Zürich': {'long_name': 'Zürich',
#   'short_name': 'ZH'},
#  'Institut für Integrative Biologie (IBZ) Departement Umweltwissenschaften ETH Zürich': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Labor für Metallphysik und Technologie ETH Zürich': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Faculté de droit Université de Fribourg': {'long_name': 'Fribourg',
#   'short_name': 'FR'},
#  'Allgemeine Psychologie und Neuropsychologie Institut für Psychologie Universität Bern': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'Filière Technique en radiologie médicale TRM Haute école de santé vaud HES-SO': {'long_name': 'Canton of Solothurn',
#   'short_name': 'SO'},
#  'Medizinische Klinik Stadtspital Triemli': {'long_name': 'Zürich',
#   'short_name': 'ZH'},
#  'Collegium Helveticum Semper-Sternwarte ETH - Zentrum': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Endocrinologica Dipartimento Ginecologia Ospedale "La Carità"': {'long_name': 'Ticino',
#   'short_name': 'TI'},
#  'Département de psychiatrie Faculté de médecine Université de Genève': {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'Centre d’Immunologie de Marseille-Luminy': {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'Institut für Unternehmensrechnung und Controlling Universität Bern': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'Kantonsschule Zürcher Unterland': {'long_name': 'Zürich',
#   'short_name': 'ZH'},
#  'Universität Basel Departement Biomedical Engineering': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  'Institut Primarstufe Pädagogische Hochschule Fachhochschule Nordwestschweiz': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  'UNI: MRC Western General Hospital  Edinburgh GB': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'South Asia Institute': {'long_name': 'Zürich', 'short_name': 'ZH'},
#  'UNI: University of Kyoto Dept of Mathematics Kyoto J': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'UNI: Academy of Sciences Institute of organi c chemistry  Moscow RUS': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'Station de Zoologie Expérimentale': {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'Institut für Pharmazeutische Biologie Universität Basel': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  'ABW Architektur + Raumplanung AG': {'long_name': 'Aargau',
#   'short_name': 'AG'},
#  'UNI: Vasilievskij ostros Malyj Prospekt  St. Petersburg RUS': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'CHUV NHC  BH 13.541': {'long_name': 'Vaud', 'short_name': 'VD'},
#  'Direction des Musées cantonaux du Valais': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Chaire de Climatologie Université de Genève': {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'Medizinische Klinik Universitätsspital Zürich': {'long_name': 'Zürich',
#   'short_name': 'ZH'},
#  "Service de Gastro-entérologie et d'Hépatologie CHUV": {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'UNI: Istituto Nazionale di Fisica Nucleare Roma I': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'UNI: Karls-University Department of Petrolog y  Praha TS': {'long_name': 'Canton of Neuchâtel',
#   'short_name': 'NE'},
#  'Institute for Corporate Communication Faculty of Communication sciences University of Lugano': {'long_name': 'Lucerne',
#   'short_name': 'LU'},
#  'Schweiz. Stiftung für die Photographie Kunsthaus': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Filière physiothérapie Haute École de Santé Genève (HEdS) HES-SO': {'long_name': 'Canton of Solothurn',
#   'short_name': 'SO'},
#  'Kantonsschule Stadelhofen': {'long_name': 'Zurich', 'short_name': 'ZH'},
#  "UNI: Inst. national de recherche Histoire de l'architecture et urbanisme Moskau RUS": {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'DüCo Sozialforschung': {'long_name': 'N/A', 'short_name': 'N/A'},
#  "Commission de recherche de l'Univ. de Fribourg, Séminaire d'histoire ancienne Univ. de Fribourg": {'long_name': 'Fribourg',
#   'short_name': 'FR'},
#  'Laboratoire de Bioénergétique Université de Genève': {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'GREEN Tox': {'long_name': 'Zürich', 'short_name': 'ZH'},
#  'UFR de philosophie Université Paris IV': {'long_name': 'Genève',
#   'short_name': 'GE'},
#  "UNI: CIRSEE Centre International de Recherch e sur l'Eau et l'Environnement Le Pecq F": {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Abt. für Zell- und Molekularpathologie Departement für Pathologie Universität Zürich': {'long_name': 'Zürich',
#   'short_name': 'ZH'},
#  'Firma BSU Büro für Siedlungs- und Umweltplanung / Broggi & Ryser': {'long_name': 'Aargau',
#   'short_name': 'AG'},
#  "Cinémathèque suisse Centre d'Archivage": {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'UNI: University of Copenhagen Zoological Ins titute  Copenhagen DK': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Büro für arbeits- und sozialpolitische Studien (Büro BASS), Bern': {'long_name': 'Aargau',
#   'short_name': 'AG'},
#  'Schweiz. Stiftung Stockalperschloss': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Centre de Microscopie Électronique Université de Lausanne': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'Laboratoire de design moléculaire computationnel EPFL - SB - ISIC - LCMD': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'Sec. de Langues et Civilisations Orientales Faculté des Lettres Université de Lausanne': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'Service de Neurochirurgie Département des Neurosciences Cliniques Hôpitaux Universitaires de Genève': {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'UNI: Friedrich-Miescher-Institut   Basel CH': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'UNI: EPF-Lausanne Laboratoire de métallurgie physique  Lausanne CH': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Versuchsanstalt für Wasserbau, Hydrologie und Glaziologie ETH Zürich': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Departement für Kunstwissenschaften Institut für Kunstgeschichte Universität Bern': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  "Hôpital de l'Enfance": {'long_name': 'Genève', 'short_name': 'GE'},
#  'Büro für Archäologie der Stadt Zürich': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'UNI: EAWAG  8600 Dübendorf CH': {'long_name': 'N/A', 'short_name': 'N/A'},
#  'Universitätsspital Zürich Hämatologie': {'long_name': 'Zürich',
#   'short_name': 'ZH'},
#  'Klinik für Hämatologie Departement Innere Medizin Universitätsspital Zürich': {'long_name': 'Zürich',
#   'short_name': 'ZH'},
#  "Laboratoire d'architecture et mobilité urbaine EPFL - ENAC - IA - LAMU": {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'Kantonsbibliothek Vadiana': {'long_name': 'Zurich', 'short_name': 'ZH'},
#  'Institut für Diagnostische, Interventionelle und Pädiatrische Radiologie Inselspital': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'Theoretical Physics Department Natioanl University of Uzbekostan': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'Institut für Neuroradiologie Departement Medizinische Universitätsspital Zürich': {'long_name': 'Zürich',
#   'short_name': 'ZH'},
#  'UNI: Schweiz. Bundesarchiv   Bern CH': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'UNI: Institut suisse de recherches expérimen tales sur le cancer  Epalinges CH': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Departement Design Zürcher Hochschule der Künste': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Abt. Innenpolitik / Vergleichende Politik Institut für Politikwissenschaft Universität Zürich': {'long_name': 'Zürich',
#   'short_name': 'ZH'},
#  'Abteilung Chronobiologie Universitäre Psychiatrische Kliniken Basel': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  'Kompetenzzentrum Forschung, Entwicklung und Beratung Pädagogische Hochschule des Kt. St.Gallen': {'long_name': 'St. Gallen',
#   'short_name': 'SG'},
#  'Institut für Musikwissenschaft Universität Bern': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'Institut für Umweltgeowissenschaften Universität Basel': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  'Seminar für Soziologie (SfS-HSG) Universität St. Gallen': {'long_name': 'Sankt Gallen',
#   'short_name': 'SG'},
#  'Département des sciences de la Terre Université de Genève': {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'Institut de langue et littérature allemandes Faculté des lettres et sciences humaines Université de Neuchâtel': {'long_name': 'Canton of Neuchâtel',
#   'short_name': 'NE'},
#  'UNI: Institute of Physics and Astronomy Ny M unkegade Building 520 Aarhus DK': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Pädiatrische Immunologie Dept. Klinisch-Biologische Wissenschaften Universität Basel': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  'Laboratoire de neurobiologie moléculaire et neuroprotéomique EPFL - SV - BMI - LMNN': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'Labor für Umweltanalytik und Mikrobiologie SOLVIT': {'long_name': 'Aargau',
#   'short_name': 'AG'},
#  'Institut für Sozial- und Präventivmedizin Universität Zürich': {'long_name': 'Zürich',
#   'short_name': 'ZH'},
#  'Condensed Matter Theory Paul Scherrer Institut': {'long_name': 'Aargau',
#   'short_name': 'AG'},
#  'UNI: Institute of Physics   Moscow RUS': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'UNI: University of Florida   Gainesville USA': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Forschungsstelle für Sicherheitspolitik und Konfliktanalyse / Bibliothek ETH-Zentrum': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Kunstmuseum Bern': {'long_name': 'Zurich', 'short_name': 'ZH'},
#  "Service of Pediatric Orthopedics Department of Pediatrics Children's Hospital, University of Geneva": {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'Laboratoire de théorie et simulation des matériaux EPFL - STI - IMX - THEOS': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'Laboratoire de métallurgie mécanique EPFL - STI - IMX - LMM': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'Laboratoire des nanomatériaux supramoléculaires et interfaces EPFL - STI - IMX - SUNMIL': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'Pain and Palliative Care Society University Medical College': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Chimie appliquée Université de Genève': {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'Abteilung Neuroradiologie Institut für Radiologie Universitätsspital Basel': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  'ecce - Gemeinschaft für Sozialforschung': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  'Fondation F.A.B.E.R': {'long_name': 'Vaud', 'short_name': 'VD'},
#  'Bündner Kunstmuseum Chur': {'long_name': 'Zürich', 'short_name': 'ZH'},
#  'Arbeitsstelle der Stiftung für kulturwissenschaftliche Forschungen': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Laboratoire de biomécanique en orthopédie EPFL - STI - CBT - LBO': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'UNI: CNRS Laboratoire de Génétique des Virus Gif-sur-Yvette F': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Massachusetts Institute of Technology Linguistics and Philosophy': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  'Departement für Innere Medizin Abteilung für Gastroenterologie': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  'Philosohpische Fakultät Universität Zürich': {'long_name': 'Zürich',
#   'short_name': 'ZH'},
#  'Département de Chimie Physique Faculté des Sciences Université de Genève': {'long_name': 'Genève',
#   'short_name': 'GE'},
#  "Unité d'Investigations Chirurgicales Département de Chirurgie Hôpital Cantonal": {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'UNI: Universität Basel Geographisches Instit ut  Basel CH': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Institute of Molecular and Atomic Physics - National Academy of Sciences of Belarus': {'long_name': 'Aargau',
#   'short_name': 'AG'},
#  'Forschungsschwerpunkt Transdisziplinarität Zürcher Hochschule der Künste Zürcher Fachhochschule': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Abteilung Experimentelle Hämatologie Departement Forschung Kantonsspital Basel': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  'Geodetical and Geophysical Research Institute of the Hungarian Academy of Sciences': {'long_name': 'Canton of Neuchâtel',
#   'short_name': 'NE'},
#  'Sciences de la Terre Département des Géosciences Université de Fribourg': {'long_name': 'Fribourg',
#   'short_name': 'FR'},
#  'Service Universitaire de Psycho- gériatrie de Lausanne Hôpital de Prilly': {'long_name': 'Vaud',
# ...
#   'short_name': 'VD'},
#  'Faculty of Forestry University of Sarajevo': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Labor für Mikro- und Nanotechnologie Paul Scherrer Institut': {'long_name': 'Aargau',
#   'short_name': 'AG'},
#  "Monumenti Storici Dipartimento dell'ambiente Ufficio Cantonale": {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Institut für Ecopreneurship Hochschule für Life Sciences Fachhochschule Nordwestschweiz': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  'Laboratoire des interfaces bioélectroniques flexibles EPFL - STI - IMT - LSBI': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'Burson-Marsteller': {'long_name': 'Aargau', 'short_name': 'AG'},
#  'Max-Planck-Institut für Psychiatrie Abteilung für Neuroimmunologie': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'Berner Fachhochschule Architektur, Holz und Bau': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'Allgemeine Sprachwissenschaft Universität Basel': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  'Haute Ecole de Santé de Genève (HEdS) HES-SO': {'long_name': 'Canton of Solothurn',
#   'short_name': 'SO'},
#  'Institut du monde antique et byzantin Faculté des lettres Université de Fribourg': {'long_name': 'Fribourg',
#   'short_name': 'FR'},
#  'Institut für Anorganische Chemie Departement Chemie Universität Basel': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  "Laboratoire de théorie et d'histoire 2 ENAC-IA EPFL": {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'Institut für Biochemie ETH Zürich': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Freies Gymnasium Zürich': {'long_name': 'Zurich', 'short_name': 'ZH'},
#  'Ordinariat für Quantitative Methoden der BWL Universität Bern': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'Endocrinologie, Diabétologie et Nutrition Département de Médecine Interne Hôpitaux Universitaires de Genève': {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'School of Medicine University of Pennsylvania': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Fondation pour le LIMC': {'long_name': 'Zurich', 'short_name': 'ZH'},
#  'UNI: EPF-Lausanne Départment de Chimie  Laus anne CH': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Architekturtheorie Institut gta ETH Zürich': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'BESSY GmbH Berliner Synchrotron': {'long_name': 'N/A', 'short_name': 'N/A'},
#  'Externer Psychiatrischer Dienst Baselland': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  'Institut Central des Hôpitaux Valaisans Département Microbiologie-Immunologie': {'long_name': 'Lucerne',
#   'short_name': 'LU'},
#  'Psychotherapeutische Abteilung Universitäre Psychiatrische Kliniken UPK': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'UNI: Comenius University Institute of Molecu lar and Subcellular Biology Bratislava SO': {'long_name': 'Canton of Neuchâtel',
#   'short_name': 'NE'},
#  'Labor für Zellbiologie der Netzhaut Augenklinik Universität Zürich': {'long_name': 'Zürich',
#   'short_name': 'ZH'},
#  'Histologie et Embryologie générale Département de médecine Université de Fribourg': {'long_name': 'Fribourg',
#   'short_name': 'FR'},
#  'Abteilung Forschung Pädagogische Hochschule Thurgau': {'long_name': 'Thurgau',
#   'short_name': 'TG'},
#  'UNI: ETH-Zürich Institut für Nutztierwissens chaften, Physiologie und Tierhaltung Zürich CH': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Schweizerischer Erdbebendienst ETH Zürich': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Istituto di Economia Aziendale Facoltà di Scienze Economiche Università della Svizzera italiana': {'long_name': 'Lucerne',
#   'short_name': 'LU'},
#  'UNI: Univesity of Western Ontario Astronomy Departement  London CDN': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Groupe de psychologie appliquée Faculté de Droit Université de Neuchâtel': {'long_name': 'Canton of Neuchâtel',
#   'short_name': 'NE'},
#  'Laboratoire de Biologie de la Reproduction et du Développement c/o M. le Prof. Maurice Auroux': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Institut für Organische Chemie Universität Bern': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'UNI: University of Cambridge Department of Z oology  Cambridge GB': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'UNI: Technical Univ. G. Asachi Lab. for Biom edical Engineering  Iasi R': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'Arcoplan': {'long_name': 'Aargau', 'short_name': 'AG'},
#  'Georgian National Museum': {'long_name': 'Zurich', 'short_name': 'ZH'},
#  'Programm für Wissenschaftsforschung Universität Basel': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  'Soziologisches Seminar Kultur- und Sozialwissenschaftliche Fakultät Universität Luzern': {'long_name': 'Luzern',
#   'short_name': 'LU'},
#  'DOKDI Dokumentationsdienst der Schweizerischen Akademie der Medizinischen Wissenschaften': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'Abteilung für klinische Radiologie Departement für klinische Veterinärmedizin': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'Professur für Zuverlässigkeitstechnik EHT-Zentrum': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  "Laboratoire d'optoélectronique quantique EPFL - SB - ICMP - LOEQ": {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'Institute of Organization and Administration Science (IOU) University of Zurich': {'long_name': 'Zürich',
#   'short_name': 'ZH'},
#  'Istituto Universitario Federale per la Formazione Professionale': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Institut für Bienengesundheit Vetsuisse Fakultät Universität Bern': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'Theologische Hochschule Basel': {'long_name': 'N/A', 'short_name': 'N/A'},
#  'Med. Bildverarbeitung  Schweizerisches Epilepsie-Zentrum': {'long_name': 'Lucerne',
#   'short_name': 'LU'},
#  'Klinik für Gynäkologie/Forschung Universitätsspital Zürich': {'long_name': 'Zürich',
#   'short_name': 'ZH'},
#  'Kompetenzgruppe "Tragwerke & Verstärkungen" iCEN Hochschule für Technik und Architektur': {'long_name': 'Canton of Solothurn',
#   'short_name': 'SO'},
#  'ZHAW Departement Gesundheit': {'long_name': 'Zurich', 'short_name': 'ZH'},
#  'Institute of Finance University of Lugano': {'long_name': 'Lucerne',
#   'short_name': 'LU'},
#  'Corporate Finance Division Wirtschaftswissenschaftliches Zentrum (WWZ) Universitaet Basel': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  'Département de Physique Université de Fribourg': {'long_name': 'Fribourg',
#   'short_name': 'FR'},
#  'Unité de Neurogérontopsychologie Service de Psychiatrie Gériatrique Hôpitaux Universitaires de Genève': {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'Schweiz. Pastoralsoz. Institut (SPI)': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  "Département d'histoire du droit et des doctrines juridiques et politiques": {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'Zentum für wirtschaftspolitische Forschung HTW Chur': {'long_name': 'St. Gallen',
#   'short_name': 'SG'},
#  'LUNDSGAARD-HANSEN, GADIENT &PARTNER Recht/Strategie/Verkehr Verkehr/Wirtschaft/Staat': {'long_name': 'Aargau',
#   'short_name': 'AG'},
#  'Strittmatter + Partner AG': {'long_name': 'Zurich', 'short_name': 'ZH'},
#  'Schweizerische Kommission für Mole- kularbiologie/ Prof. Angela Krämer Biologie Cellulaire/ Science III': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Planconsult W+B AG': {'long_name': 'Aargau', 'short_name': 'AG'},
#  'Universitäts-Kinderklinik  Universität Bern': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'Laboratoire de Physique des Hautes Energies SB-IPEP-LPHE EPFL': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'Hospiz im Park Klinik für palliative Medizin, Pflege und Begleitung': {'long_name': 'Lucerne',
#   'short_name': 'LU'},
#  'Transplantationsimmunologie und Nephrologie Universitätsspital Basel': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Istituto Oncologico della svizzera Italiana Ente Ospedaliero Cantonale': {'long_name': 'Ticino',
#   'short_name': 'TI'},
#  'Institut ERASM Etude et recherches appliquées à la sociologie et au marketing': {'long_name': 'Aargau',
#   'short_name': 'AG'},
#  "Inst. d'Histoire de la Médec. et de la Santé Centre médical universitaire CMU Université de Genève": {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'EPFL - IIG': {'long_name': 'Vaud', 'short_name': 'VD'},
#  'UNI: Universität Zürich Physikalisches Insti tut  Zürich CH': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Kardiologie und Nuklearmedizin Universitätsspital Zürich': {'long_name': 'Zürich',
#   'short_name': 'ZH'},
#  'UNI: ETH-Z Mikrobiologisches Institut  Züric h CH': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Séminaire de préhistoire Université de Neuchâtel': {'long_name': 'Canton of Neuchâtel',
#   'short_name': 'NE'},
#  'UNI: Russian Academy of Sciences General Phy sics Institute  Moscow RUS': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'Abteilung für Schweizer Geschichte Historisches Institut Universität Bern': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  "Centre d'études en sciences naturelles de l'environnement Université de Genève": {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'Lab. de biologie du vieillissement Département de Gériatrie': {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'Collège Cantonal Saint-Michel': {'long_name': 'Zurich', 'short_name': 'ZH'},
#  'Technische Universität München Lehrstuhl für Botanik': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Association internationale de la sécurité sociale (AISS)': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Institut des matériaux EPFL - STI - IMX': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'Département de Psychiatrie Unité de Psychopharmacologie Clinique Hôpitaux Universitaires de Genève': {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'Kompetenzzentr. Regional- & Stadtentwicklung Institut für Soziokulturelle Entwicklung Hoschschule Luzern - Soziale Arbeit': {'long_name': 'Lucerne',
#   'short_name': 'LU'},
#  'Département de Chimie Minérale et Analytique Université de Genève': {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'Institut für Parasitologie Universität Bern': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'Department of Systems Biology Dana-Farber Cancer Institute Harvard Medical School': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'CERN': {'long_name': 'N/A', 'short_name': 'N/A'},
#  'ABB Semiconductors AG Forschung & Entwicklung': {'long_name': 'Aargau',
#   'short_name': 'AG'},
#  'Abteilung für Wirtschaftsgeographie Geographisches Institut Universität Zürich': {'long_name': 'Zürich',
#   'short_name': 'ZH'},
#  'Institut für Landschaftsarchitektur ETH Zürich': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Musikhochschule der Musik-Akademie der Stadt Basel': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  "Centre d'analyse minérale Sciences de la Terre Université de Lausanne": {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'UNI: Institute of Physiology Academy of Scie nces of the Cseck Republic Prag TS': {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'CHUV Institut de physiopathologie': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'Zentrum für Klinische Forschung Universitätsspital Zürich': {'long_name': 'Zürich',
#   'short_name': 'ZH'},
#  'Institut für Automatik ETH Zürich': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Départment de Pédiatrie et de Pathologie-Immunologie Université de Genève': {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'Büro für Raum- und Umweltplanung': {'long_name': 'Aargau',
#   'short_name': 'AG'},
#  'Clinica Psihiatrica': {'long_name': 'Vaud', 'short_name': 'VD'},
#  'Arbeitsgruppe für Umwelthygiene Veterinär-medizinische Fakultät': {'long_name': 'Zürich',
#   'short_name': 'ZH'},
#  'Institut für Nichtmetallische anorganische Werkstoffe ETH-Hönggerberg': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Abteilung für Systematische Anatomie Institut für Anatomie Universität Bern': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'Zürcher Hochschule der Künste': {'long_name': 'Zurich', 'short_name': 'ZH'},
#  'Laboratoire de physique théorique des particules EPFL - SB - ITP - LPTP': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'UNI: Pro Grigioni Italiano  Chur CH': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  "Département de l'Imagerie et Sciences de l'Information Médicale Hôpitaux Universitaires de Genève": {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'UNI: University of Liverpool Dept of Statist ics & Computational Mathematics Liverpool GB': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'IBM Research GmbH': {'long_name': 'Aargau', 'short_name': 'AG'},
#  'Institut für Italianistik Philosophisch-Historische Fakultät Universität Basel': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  'Institute for Art Education Departement Kulturanalysen und Vermittlung Zürcher Hochschule der Künste': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'UNI: Universität Basel Aegyptologisches Semi nar  Basel CH': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'EPFL SV ISREC UPRAD': {'long_name': 'N/A', 'short_name': 'N/A'},
#  'Cimera Network': {'long_name': 'Genève', 'short_name': 'GE'},
#  'Centre Universitaire de Traitements et Réadaptation Cevey-Sylvana': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'IMSI Haute Ecole de Gestion ARC': {'long_name': 'Canton of Solothurn',
#   'short_name': 'SO'},
#  'Unité de Néphrologie et Métabolisme Département de Pédiatrie Hôpitaux Universitaires de Genève': {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'Departement für Innere Vet. Medizin Universität Zürich': {'long_name': 'Zürich',
#   'short_name': 'ZH'},
#  'Laboratoire de chimie physique théorique EPFL - SB - ISIC - LCPT': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  "Unité d'Epileptologie Clinique Hôpital Cantonal Universitaire": {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'Volkswirtschaftliches Institut Abteilung Oekonometrie': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Nukleare Energieforschung Paul Scherrer Institut': {'long_name': 'Aargau',
#   'short_name': 'AG'},
#  'Laboratorium für dünne Schichten und Photovoltaik EMPA': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Departement für Biologie Universität Bern': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  "Institut d'Archéologie et des Sciences de l'Antiquité Université de Lausanne": {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'Service archéologique Canton de Fribourg': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Institut für Nuklearmedizin Universitätsspital Zürich': {'long_name': 'Zürich',
#   'short_name': 'ZH'},
#  'Lab. de Diagnostique moléculaire Service de génétique médicale Dépt Gynécologie et obstétrique': {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'Institut für Anorganische und Angewandte Chemie Universität Hamburg': {'long_name': 'Zürich',
#   'short_name': 'ZH'},
#  'UNI: Russian Academy of Sciences Institute o f Precambrian Geology and Geochronology St. Petersburg RUS': {'long_name': 'Canton of Bern',
#   'short_name': 'BE'},
#  'Université de Lausanne Institut des Sciences du Sport (ISSUL)': {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  "Section d'Italien Faculté des Lettres Université de Lausanne": {'long_name': 'Vaud',
#   'short_name': 'VD'},
#  'Laboratoire de Recherches Division de Rhumatologie Hôpital Cantonal Universitaire GE': {'long_name': 'Genève',
#   'short_name': 'GE'},
#  'Aquatic Ecology  Eawag': {'long_name': 'N/A', 'short_name': 'N/A'},
#  'Functional Genomics Center Zürich ETH Universität Zürich': {'long_name': 'Zurich',
#   'short_name': 'ZH'},
#  'Littérature et Langue française Université Paris-Sorbonne - Paris IV': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'UNI: Universität Bern M.E. Müller-Institut f ür Biomechanik  Bern CH': {'long_name': 'N/A',
#   'short_name': 'N/A'},
#  'Geologisch-Paläontologisches Institut Universität Basel': {'long_name': 'Basel-Stadt',
#   'short_name': 'BS'},
#  'EPFL - FSV - GHI - UPKIN': {'long_name': 'Vaud', 'short_name': 'VD'},
#  'Atelier 5 Architekten und Planer': {'long_name': 'Aargau',
#   'short_name': 'AG'},
#  ...}

# %%
canton_shortname_series = pd.Series(canton_shortname_table, name='Canton Shortname')
canton_shortname_series.size
# Out:
# 53059

# %%
canton_longname_series = pd.Series(canton_longname_table, name='Canton Longname')
canton_longname_series.size
# Out:
# 53059

# %%
len(p3_grant_export_data.index)
# Out:
# 53059

# %%
# Reindex the dataframe to make the match with cantons
p3_grant_export_data_reindex = p3_grant_export_data.reset_index(drop=True)
p3_grant_export_data_reindex
# Out:
#                                  Funding Instrument  \
# 0                      Project funding (Div. I-III)
# 1                      Project funding (Div. I-III)
# 2                      Project funding (Div. I-III)
# 3                      Project funding (Div. I-III)
# 4                      Project funding (Div. I-III)
# 5                      Project funding (Div. I-III)
# 6                      Project funding (Div. I-III)
# 7                      Project funding (Div. I-III)
# 8                      Project funding (Div. I-III)
# 9                      Project funding (Div. I-III)
# 10                     Project funding (Div. I-III)
# 11                     Project funding (Div. I-III)
# 12                     Project funding (Div. I-III)
# 13                     Project funding (Div. I-III)
# 14                     Project funding (Div. I-III)
# 15                     Project funding (Div. I-III)
# 16                     Project funding (Div. I-III)
# 17                     Project funding (Div. I-III)
# 18                     Project funding (Div. I-III)
# 19                     Project funding (Div. I-III)
# 20                     Project funding (Div. I-III)
# 21                     Project funding (Div. I-III)
# 22                     Project funding (Div. I-III)
# 23                     Project funding (Div. I-III)
# 24                     Project funding (Div. I-III)
# 25                     Project funding (Div. I-III)
# 26                     Project funding (Div. I-III)
# 27                     Project funding (Div. I-III)
# 28                     Project funding (Div. I-III)
# 29                     Project funding (Div. I-III)
# ...                                             ...
# 53029                            Publication grants
# 53030           International short research visits
# 53031           International short research visits
# 53032           International short research visits
# 53033           International short research visits
# 53034           International short research visits
# 53035           International short research visits
# 53036           International short research visits
# 53037           International short research visits
# 53038           International short research visits
# 53039           International short research visits
# 53040                        Scientific Conferences
# 53041  NRP 68 Sustainable Use of Soil as a Resource
# 53042  NRP 68 Sustainable Use of Soil as a Resource
# 53043  NRP 68 Sustainable Use of Soil as a Resource
# 53044           International short research visits
# 53045           International Exploratory Workshops
# 53046           International short research visits
# 53047           International short research visits
# 53048                        Scientific Conferences
# 53049                        Scientific Conferences
# 53050           International short research visits
# 53051           International short research visits
# 53052           International short research visits
# 53053                        Scientific Conferences
# 53054                        Scientific Conferences
# 53055                        Scientific Conferences
# 53056           International short research visits
# 53057           International short research visits
# 53058           International short research visits
#
#                          Funding Instrument Hierarchy  \
# 0                                     Project funding
# 1                                     Project funding
# 2                                     Project funding
# 3                                     Project funding
# 4                                     Project funding
# 5                                     Project funding
# 6                                     Project funding
# 7                                     Project funding
# 8                                     Project funding
# 9                                     Project funding
# 10                                    Project funding
# 11                                    Project funding
# 12                                    Project funding
# 13                                    Project funding
# 14                                    Project funding
# 15                                    Project funding
# 16                                    Project funding
# 17                                    Project funding
# 18                                    Project funding
# 19                                    Project funding
# 20                                    Project funding
# 21                                    Project funding
# 22                                    Project funding
# 23                                    Project funding
# 24                                    Project funding
# 25                                    Project funding
# 26                                    Project funding
# 27                                    Project funding
# 28                                    Project funding
# 29                                    Project funding
# ...                                               ...
# 53029                           Science communication
# 53030                                         Careers
# 53031                                         Careers
# 53032                                         Careers
# 53033                                         Careers
# 53034                                         Careers
# 53035                                         Careers
# 53036                                         Careers
# 53037                                         Careers
# 53038                                         Careers
# 53039                                         Careers
# 53040                           Science communication
# 53041  Programmes;National Research Programmes (NRPs)
# 53042  Programmes;National Research Programmes (NRPs)
# 53043  Programmes;National Research Programmes (NRPs)
# 53044                                         Careers
# 53045                           Science communication
# 53046                                         Careers
# 53047                                         Careers
# 53048                           Science communication
# 53049                           Science communication
# 53050                                         Careers
# 53051                                         Careers
# 53052                                         Careers
# 53053                           Science communication
# 53054                           Science communication
# 53055                           Science communication
# 53056                                         Careers
# 53057                                         Careers
# 53058                                         Careers
#
#                                              Institution  \
# 0                                                    NaN
# 1      Faculté de Psychologie et des Sciences de l'Ed...
# 2      Kommission für das Corpus philosophorum medii ...
# 3      Abt. Handschriften und Alte Drucke Bibliothek ...
# 4                           Schweiz. Thesauruskommission
# 5      Séminaire de politique économique, d'économie ...
# 6      Institut für ökumenische Studien Université de...
# 7              Ostasiatisches Seminar Universität Zürich
# 8                                                    NaN
# 9      Laboratoire de Didactique et Epistémologie des...
# 10     Klinische Psychologie und Psychotherapie Insti...
# 11     Schweizerische Rechtsquellen c/o Universität Z...
# 12     Département de Sociologie Faculté des Sciences...
# 13     Institut für Volkswirtschaft WWZ / FGS Univers...
# 14            Soziologisches Institut Universität Zürich
# 15                                 Forschungszentrum FAL
# 16     Faculté de Psychologie et des Sciences de l'Ed...
# 17            Soziologisches Institut Universität Zürich
# 18                                                   NaN
# 19                                                   NaN
# 20     Faculté de Psychologie et des Sciences de l'Ed...
# 21                                                   NaN
# 22     Forschungsbereich Politisches Verhalten und Oe...
# 23     Département des langues et des littératures fr...
# 24                                                   NaN
# 25                                                   NaN
# 26            Schweizerische Gesellschaft für Volkskunde
# 27                         Kuratorium Carl J. Burckhardt
# 28                                                   NaN
# 29     Eidg. Forschungsanstalt für Wald, Schnee und L...
# ...                                                  ...
# 53029  Institut Sozialmanagement und Sozialpolitik Ho...
# 53030                Stiftung Bibliothek Werner Oechslin
# 53031  School of Geographical Sciences University of ...
# 53032                                                NaN
# 53033              CSIRO Marine and Atmospheric Research
# 53034                                                NaN
# 53035     Departement Geographie, SIE Universität Zürich
# 53036  CReAM Department of Economics University Colle...
# 53037                                                NaN
# 53038                                              Eawag
# 53039                      Catholic University of Bukavu
# 53040  Fondation Jean Monnet pour l'Europe Centre de ...
# 53041  Planning of Landscape and Urban Systems Instit...
# 53042  Forschungsanstalt Agroscope Reckenholz-Tänikon...
# 53043  Forschung und Beratung in Wirtschaft und Polit...
# 53044            Zoologisches Institut Universität Basel
# 53045  Zentrum für Religion, Wirtschaft und Politik T...
# 53046  Abteilung für Neuropsychologie Zentrum für Kog...
# 53047                                                NaN
# 53048         Abteilung für Indologie Universität Zürich
# 53049  Institut Religions, Cultures, Modernité FTSR U...
# 53050                                                NaN
# 53051  Department of Physics University of Massachusetts
# 53052                                                NaN
# 53053     Haute École d'art et de design - Genève HES-SO
# 53054  Departement Design Zürcher Hochschule der Küns...
# 53055  Institute Performing Arts and Film Zürcher Hoc...
# 53056  Department of Electrical Engineering and Compu...
# 53057  Département de Biologie Faculté des Sciences U...
# 53058  The Forsyth Institute Department of Microbiolo...
#
#                                               University  Start Date  \
# 0                                   Nicht zuteilbar - NA  01.10.1975
# 1                              Université de Genève - GE  01.10.1975
# 2                NPO (Biblioth., Museen, Verwalt.) - NPO  01.03.1976
# 3                                 Universität Basel - BS  01.10.1975
# 4                NPO (Biblioth., Museen, Verwalt.) - NPO  01.01.1976
# 5                            Université de Fribourg - FR  01.01.1976
# 6                            Université de Fribourg - FR  01.01.1976
# 7                                Universität Zürich - ZH  01.10.1975
# 8                            Université de Lausanne - LA  01.10.1975
# 9                              Université de Genève - GE  01.10.1975
# 10                           Université de Fribourg - FR  01.10.1975
# 11               NPO (Biblioth., Museen, Verwalt.) - NPO  01.10.1975
# 12                             Université de Genève - GE  01.10.1975
# 13                                Universität Basel - BS  01.10.1975
# 14                               Universität Zürich - ZH  01.10.1975
# 15                           Université de Fribourg - FR  01.10.1975
# 16                             Université de Genève - GE  01.10.1975
# 17                               Universität Zürich - ZH  01.01.1976
# 18                                  Nicht zuteilbar - NA  01.01.1976
# 19                           Université de Lausanne - LA  01.12.1975
# 20                             Université de Genève - GE  01.10.1975
# 21                                 Universität Bern - BE  01.10.1975
# 22                               Universität Zürich - ZH  01.01.1976
# 23                             Université de Genève - GE  01.10.1975
# 24                                  Nicht zuteilbar - NA  01.01.1976
# 25                                  Nicht zuteilbar - NA  01.10.1975
# 26               NPO (Biblioth., Museen, Verwalt.) - NPO  01.10.1975
# 27               NPO (Biblioth., Museen, Verwalt.) - NPO  01.10.1975
# 28                               Universität Zürich - ZH  01.10.1975
# 29     Eidg. Forschungsanstalt für Wald,Schnee,Land -...  01.10.1975
# ...                                                  ...         ...
# 53029                           Hochschule Luzern - HSLU  01.08.2016
# 53030                                                NaN  01.07.2016
# 53031                                                NaN  01.08.2016
# 53032                                                NaN  01.07.2016
# 53033                                                NaN  01.08.2016
# 53034                                                NaN  01.07.2016
# 53035                                                NaN  01.08.2016
# 53036                                                NaN  01.09.2016
# 53037                                                NaN  01.08.2016
# 53038                                                NaN  01.09.2016
# 53039                                                NaN  01.09.2016
# 53040            NPO (Biblioth., Museen, Verwalt.) - NPO  01.10.2016
# 53041                                  ETH Zürich - ETHZ  01.10.2016
# 53042                Forschungsanstalten Agroscope - AGS  01.10.2016
# 53043                       Firmen/Privatwirtschaft - FP  01.09.2016
# 53044                                                NaN  01.09.2016
# 53045                             Universität Basel - BS  01.10.2016
# 53046                                                NaN  01.08.2016
# 53047                                                NaN  01.08.2016
# 53048                            Universität Zürich - ZH  01.10.2016
# 53049                        Université de Lausanne - LA  01.10.2016
# 53050                                                NaN  01.10.2016
# 53051                                                NaN  01.10.2016
# 53052                                                NaN  01.09.2016
# 53053                 HES de Suisse occidentale - HES-SO  01.10.2016
# 53054             Zürcher Fachhochschule (ohne PH) - ZFH  01.10.2016
# 53055             Zürcher Fachhochschule (ohne PH) - ZFH  01.09.2016
# 53056                                                NaN  01.09.2016
# 53057                                                NaN  01.09.2016
# 53058                                                NaN  01.10.2016
#
#          End Date Approved Amount
# 0      30.09.1976        11619.00
# 1      30.09.1976        41022.00
# 2      28.02.1985        79732.00
# 3      30.09.1976        52627.00
# 4      30.04.1978       120042.00
# 5      31.12.1978        53009.00
# 6      31.12.1976        25403.00
# 7      31.03.1977        47100.00
# 8      31.03.1977        25814.00
# 9      30.09.1978       360000.00
# 10     31.12.1978       153886.00
# 11     30.09.1978       862200.00
# 12     30.09.1977       116991.00
# 13     31.12.1978       112664.00
# 14     31.12.1975         5000.00
# 15     30.09.1977       204018.00
# 16     30.09.1977       149485.00
# 17     31.08.1977        83983.00
# 18     31.12.1976        38152.00
# 19     31.01.1977        14138.00
# 20     30.09.1978       164602.00
# 21     30.04.1978       147795.00
# 22     30.06.1977        24552.00
# 23     30.09.1978        44802.00
# 24     31.12.1979        56000.00
# 25     30.09.1977       152535.00
# 26     30.09.1976       225000.00
# 27     30.04.1978       179124.00
# 28     31.03.1976        20000.00
# 29     30.09.1978       445198.00
# ...           ...             ...
# 53029  31.07.2017         1898.00
# 53030  30.09.2016         9300.00
# 53031  31.10.2016         9500.00
# 53032  31.07.2016         4000.00
# 53033  31.10.2016        11000.00
# 53034  31.08.2016         7500.00
# 53035  30.09.2016         8000.00
# 53036  30.11.2016         9300.00
# 53037  30.09.2016         7000.00
# 53038  31.10.2016         6000.00
# 53039  30.09.2016         4500.00
# 53040  31.12.2016         2800.00
# 53041  30.09.2017        99952.00
# 53042  31.12.2017        98040.00
# 53043  28.02.2018       100000.00
# 53044  30.11.2016        10500.00
# 53045  31.12.2016        10030.00
# 53046  31.10.2016         7870.00
# 53047  31.08.2016         3150.00
# 53048  31.12.2016        10600.00
# 53049  31.12.2016         2515.00
# 53050  31.10.2016         3500.00
# 53051  31.10.2016         4000.00
# 53052  30.09.2016         3550.00
# 53053  31.12.2016         3000.00
# 53054  31.12.2016         1000.00
# 53055  30.11.2016         2000.00
# 53056  31.12.2016        10500.00
# 53057  30.11.2016         9500.00
# 53058  30.11.2016         7000.00
#
# [53059 rows x 7 columns]

# %%
# Let's add the cantons to our dataframe !
p3_grant_cantons = pd.concat([p3_grant_export_data_reindex, canton_longname_series, canton_shortname_series], axis=1)
p3_grant_cantons.columns.get_value
p3_grant_cantons
# Out:
#                                  Funding Instrument  \
# 0                      Project funding (Div. I-III)
# 1                      Project funding (Div. I-III)
# 2                      Project funding (Div. I-III)
# 3                      Project funding (Div. I-III)
# 4                      Project funding (Div. I-III)
# 5                      Project funding (Div. I-III)
# 6                      Project funding (Div. I-III)
# 7                      Project funding (Div. I-III)
# 8                      Project funding (Div. I-III)
# 9                      Project funding (Div. I-III)
# 10                     Project funding (Div. I-III)
# 11                     Project funding (Div. I-III)
# 12                     Project funding (Div. I-III)
# 13                     Project funding (Div. I-III)
# 14                     Project funding (Div. I-III)
# 15                     Project funding (Div. I-III)
# 16                     Project funding (Div. I-III)
# 17                     Project funding (Div. I-III)
# 18                     Project funding (Div. I-III)
# 19                     Project funding (Div. I-III)
# 20                     Project funding (Div. I-III)
# 21                     Project funding (Div. I-III)
# 22                     Project funding (Div. I-III)
# 23                     Project funding (Div. I-III)
# 24                     Project funding (Div. I-III)
# 25                     Project funding (Div. I-III)
# 26                     Project funding (Div. I-III)
# 27                     Project funding (Div. I-III)
# 28                     Project funding (Div. I-III)
# 29                     Project funding (Div. I-III)
# ...                                             ...
# 53029                            Publication grants
# 53030           International short research visits
# 53031           International short research visits
# 53032           International short research visits
# 53033           International short research visits
# 53034           International short research visits
# 53035           International short research visits
# 53036           International short research visits
# 53037           International short research visits
# 53038           International short research visits
# 53039           International short research visits
# 53040                        Scientific Conferences
# 53041  NRP 68 Sustainable Use of Soil as a Resource
# 53042  NRP 68 Sustainable Use of Soil as a Resource
# 53043  NRP 68 Sustainable Use of Soil as a Resource
# 53044           International short research visits
# 53045           International Exploratory Workshops
# 53046           International short research visits
# 53047           International short research visits
# 53048                        Scientific Conferences
# 53049                        Scientific Conferences
# 53050           International short research visits
# 53051           International short research visits
# 53052           International short research visits
# 53053                        Scientific Conferences
# 53054                        Scientific Conferences
# 53055                        Scientific Conferences
# 53056           International short research visits
# 53057           International short research visits
# 53058           International short research visits
#
#                          Funding Instrument Hierarchy  \
# 0                                     Project funding
# 1                                     Project funding
# 2                                     Project funding
# 3                                     Project funding
# 4                                     Project funding
# 5                                     Project funding
# 6                                     Project funding
# 7                                     Project funding
# 8                                     Project funding
# 9                                     Project funding
# 10                                    Project funding
# 11                                    Project funding
# 12                                    Project funding
# 13                                    Project funding
# 14                                    Project funding
# 15                                    Project funding
# 16                                    Project funding
# 17                                    Project funding
# 18                                    Project funding
# 19                                    Project funding
# 20                                    Project funding
# 21                                    Project funding
# 22                                    Project funding
# 23                                    Project funding
# 24                                    Project funding
# 25                                    Project funding
# 26                                    Project funding
# 27                                    Project funding
# 28                                    Project funding
# 29                                    Project funding
# ...                                               ...
# 53029                           Science communication
# 53030                                         Careers
# 53031                                         Careers
# 53032                                         Careers
# 53033                                         Careers
# 53034                                         Careers
# 53035                                         Careers
# 53036                                         Careers
# 53037                                         Careers
# 53038                                         Careers
# 53039                                         Careers
# 53040                           Science communication
# 53041  Programmes;National Research Programmes (NRPs)
# 53042  Programmes;National Research Programmes (NRPs)
# 53043  Programmes;National Research Programmes (NRPs)
# 53044                                         Careers
# 53045                           Science communication
# 53046                                         Careers
# 53047                                         Careers
# 53048                           Science communication
# 53049                           Science communication
# 53050                                         Careers
# 53051                                         Careers
# 53052                                         Careers
# 53053                           Science communication
# 53054                           Science communication
# 53055                           Science communication
# 53056                                         Careers
# 53057                                         Careers
# 53058                                         Careers
#
#                                              Institution  \
# 0                                                    NaN
# 1      Faculté de Psychologie et des Sciences de l'Ed...
# 2      Kommission für das Corpus philosophorum medii ...
# 3      Abt. Handschriften und Alte Drucke Bibliothek ...
# 4                           Schweiz. Thesauruskommission
# 5      Séminaire de politique économique, d'économie ...
# 6      Institut für ökumenische Studien Université de...
# 7              Ostasiatisches Seminar Universität Zürich
# 8                                                    NaN
# 9      Laboratoire de Didactique et Epistémologie des...
# 10     Klinische Psychologie und Psychotherapie Insti...
# 11     Schweizerische Rechtsquellen c/o Universität Z...
# 12     Département de Sociologie Faculté des Sciences...
# 13     Institut für Volkswirtschaft WWZ / FGS Univers...
# 14            Soziologisches Institut Universität Zürich
# 15                                 Forschungszentrum FAL
# 16     Faculté de Psychologie et des Sciences de l'Ed...
# 17            Soziologisches Institut Universität Zürich
# 18                                                   NaN
# 19                                                   NaN
# 20     Faculté de Psychologie et des Sciences de l'Ed...
# 21                                                   NaN
# 22     Forschungsbereich Politisches Verhalten und Oe...
# 23     Département des langues et des littératures fr...
# 24                                                   NaN
# 25                                                   NaN
# 26            Schweizerische Gesellschaft für Volkskunde
# 27                         Kuratorium Carl J. Burckhardt
# 28                                                   NaN
# 29     Eidg. Forschungsanstalt für Wald, Schnee und L...
# ...                                                  ...
# 53029  Institut Sozialmanagement und Sozialpolitik Ho...
# 53030                Stiftung Bibliothek Werner Oechslin
# 53031  School of Geographical Sciences University of ...
# 53032                                                NaN
# 53033              CSIRO Marine and Atmospheric Research
# 53034                                                NaN
# 53035     Departement Geographie, SIE Universität Zürich
# 53036  CReAM Department of Economics University Colle...
# 53037                                                NaN
# 53038                                              Eawag
# 53039                      Catholic University of Bukavu
# 53040  Fondation Jean Monnet pour l'Europe Centre de ...
# 53041  Planning of Landscape and Urban Systems Instit...
# 53042  Forschungsanstalt Agroscope Reckenholz-Tänikon...
# 53043  Forschung und Beratung in Wirtschaft und Polit...
# 53044            Zoologisches Institut Universität Basel
# 53045  Zentrum für Religion, Wirtschaft und Politik T...
# 53046  Abteilung für Neuropsychologie Zentrum für Kog...
# 53047                                                NaN
# 53048         Abteilung für Indologie Universität Zürich
# 53049  Institut Religions, Cultures, Modernité FTSR U...
# 53050                                                NaN
# 53051  Department of Physics University of Massachusetts
# 53052                                                NaN
# 53053     Haute École d'art et de design - Genève HES-SO
# 53054  Departement Design Zürcher Hochschule der Küns...
# 53055  Institute Performing Arts and Film Zürcher Hoc...
# 53056  Department of Electrical Engineering and Compu...
# 53057  Département de Biologie Faculté des Sciences U...
# 53058  The Forsyth Institute Department of Microbiolo...
#
#                                               University  Start Date  \
# 0                                   Nicht zuteilbar - NA  01.10.1975
# 1                              Université de Genève - GE  01.10.1975
# 2                NPO (Biblioth., Museen, Verwalt.) - NPO  01.03.1976
# 3                                 Universität Basel - BS  01.10.1975
# 4                NPO (Biblioth., Museen, Verwalt.) - NPO  01.01.1976
# 5                            Université de Fribourg - FR  01.01.1976
# 6                            Université de Fribourg - FR  01.01.1976
# 7                                Universität Zürich - ZH  01.10.1975
# 8                            Université de Lausanne - LA  01.10.1975
# 9                              Université de Genève - GE  01.10.1975
# 10                           Université de Fribourg - FR  01.10.1975
# 11               NPO (Biblioth., Museen, Verwalt.) - NPO  01.10.1975
# 12                             Université de Genève - GE  01.10.1975
# 13                                Universität Basel - BS  01.10.1975
# 14                               Universität Zürich - ZH  01.10.1975
# 15                           Université de Fribourg - FR  01.10.1975
# 16                             Université de Genève - GE  01.10.1975
# 17                               Universität Zürich - ZH  01.01.1976
# 18                                  Nicht zuteilbar - NA  01.01.1976
# 19                           Université de Lausanne - LA  01.12.1975
# 20                             Université de Genève - GE  01.10.1975
# 21                                 Universität Bern - BE  01.10.1975
# 22                               Universität Zürich - ZH  01.01.1976
# 23                             Université de Genève - GE  01.10.1975
# 24                                  Nicht zuteilbar - NA  01.01.1976
# 25                                  Nicht zuteilbar - NA  01.10.1975
# 26               NPO (Biblioth., Museen, Verwalt.) - NPO  01.10.1975
# 27               NPO (Biblioth., Museen, Verwalt.) - NPO  01.10.1975
# 28                               Universität Zürich - ZH  01.10.1975
# 29     Eidg. Forschungsanstalt für Wald,Schnee,Land -...  01.10.1975
# ...                                                  ...         ...
# 53029                           Hochschule Luzern - HSLU  01.08.2016
# 53030                                                NaN  01.07.2016
# 53031                                                NaN  01.08.2016
# 53032                                                NaN  01.07.2016
# 53033                                                NaN  01.08.2016
# 53034                                                NaN  01.07.2016
# 53035                                                NaN  01.08.2016
# 53036                                                NaN  01.09.2016
# 53037                                                NaN  01.08.2016
# 53038                                                NaN  01.09.2016
# 53039                                                NaN  01.09.2016
# 53040            NPO (Biblioth., Museen, Verwalt.) - NPO  01.10.2016
# 53041                                  ETH Zürich - ETHZ  01.10.2016
# 53042                Forschungsanstalten Agroscope - AGS  01.10.2016
# 53043                       Firmen/Privatwirtschaft - FP  01.09.2016
# 53044                                                NaN  01.09.2016
# 53045                             Universität Basel - BS  01.10.2016
# 53046                                                NaN  01.08.2016
# 53047                                                NaN  01.08.2016
# 53048                            Universität Zürich - ZH  01.10.2016
# 53049                        Université de Lausanne - LA  01.10.2016
# 53050                                                NaN  01.10.2016
# 53051                                                NaN  01.10.2016
# 53052                                                NaN  01.09.2016
# 53053                 HES de Suisse occidentale - HES-SO  01.10.2016
# 53054             Zürcher Fachhochschule (ohne PH) - ZFH  01.10.2016
# 53055             Zürcher Fachhochschule (ohne PH) - ZFH  01.09.2016
# 53056                                                NaN  01.09.2016
# 53057                                                NaN  01.09.2016
# 53058                                                NaN  01.10.2016
#
#          End Date Approved Amount      Canton Longname Canton Shortname
# 0      30.09.1976        11619.00                  N/A              N/A
# 1      30.09.1976        41022.00               Genève               GE
# 2      28.02.1985        79732.00               Zurich               ZH
# 3      30.09.1976        52627.00          Basel-Stadt               BS
# 4      30.04.1978       120042.00               Zurich               ZH
# 5      31.12.1978        53009.00             Fribourg               FR
# 6      31.12.1976        25403.00             Fribourg               FR
# 7      31.03.1977        47100.00               Zürich               ZH
# 8      31.03.1977        25814.00                 Vaud               VD
# 9      30.09.1978       360000.00               Genève               GE
# 10     31.12.1978       153886.00             Fribourg               FR
# 11     30.09.1978       862200.00               Zurich               ZH
# 12     30.09.1977       116991.00               Genève               GE
# 13     31.12.1978       112664.00          Basel-Stadt               BS
# 14     31.12.1975         5000.00               Zürich               ZH
# 15     30.09.1977       204018.00             Fribourg               FR
# 16     30.09.1977       149485.00               Genève               GE
# 17     31.08.1977        83983.00               Zürich               ZH
# 18     31.12.1976        38152.00                  N/A              N/A
# 19     31.01.1977        14138.00                 Vaud               VD
# 20     30.09.1978       164602.00               Genève               GE
# 21     30.04.1978       147795.00       Canton of Bern               BE
# 22     30.06.1977        24552.00               Zürich               ZH
# 23     30.09.1978        44802.00               Genève               GE
# 24     31.12.1979        56000.00                  N/A              N/A
# 25     30.09.1977       152535.00                  N/A              N/A
# 26     30.09.1976       225000.00               Zurich               ZH
# 27     30.04.1978       179124.00               Zurich               ZH
# 28     31.03.1976        20000.00               Zürich               ZH
# 29     30.09.1978       445198.00                 Vaud               VD
# ...           ...             ...                  ...              ...
# 53029  31.07.2017         1898.00              Lucerne               LU
# 53030  30.09.2016         9300.00                  N/A              N/A
# 53031  31.10.2016         9500.00                  N/A              N/A
# 53032  31.07.2016         4000.00                  N/A              N/A
# 53033  31.10.2016        11000.00                  N/A              N/A
# 53034  31.08.2016         7500.00                  N/A              N/A
# 53035  30.09.2016         8000.00                  N/A              N/A
# 53036  30.11.2016         9300.00                  N/A              N/A
# 53037  30.09.2016         7000.00                  N/A              N/A
# 53038  31.10.2016         6000.00                  N/A              N/A
# 53039  30.09.2016         4500.00                  N/A              N/A
# 53040  31.12.2016         2800.00               Zurich               ZH
# 53041  30.09.2017        99952.00               Zurich               ZH
# 53042  31.12.2017        98040.00       Canton of Bern               BE
# 53043  28.02.2018       100000.00               Aargau               AG
# 53044  30.11.2016        10500.00                  N/A              N/A
# 53045  31.12.2016        10030.00          Basel-Stadt               BS
# 53046  31.10.2016         7870.00                  N/A              N/A
# 53047  31.08.2016         3150.00                  N/A              N/A
# 53048  31.12.2016        10600.00               Zürich               ZH
# 53049  31.12.2016         2515.00                 Vaud               VD
# 53050  31.10.2016         3500.00                  N/A              N/A
# 53051  31.10.2016         4000.00                  N/A              N/A
# 53052  30.09.2016         3550.00                  N/A              N/A
# 53053  31.12.2016         3000.00  Canton of Solothurn               SO
# 53054  31.12.2016         1000.00               Zurich               ZH
# 53055  30.11.2016         2000.00               Zurich               ZH
# 53056  31.12.2016        10500.00                  N/A              N/A
# 53057  30.11.2016         9500.00                  N/A              N/A
# 53058  30.11.2016         7000.00                  N/A              N/A
#
# [53059 rows x 9 columns]

# %% [markdown]
# Now we have the cantons associated with the universities/institutions :)
# We save the dataframe into several formats, just in case, in order to use them in another notebook.

# %%
try:
    p3_grant_cantons.to_csv('P3_Cantons.csv', encoding='utf-8')
except PermissionError:
    print("Couldn't access to the file. Maybe close Excel and try again :)")

# %%
p3_grant_cantons_json = p3_grant_cantons.to_json()
with open('P3_cantons.json', 'w') as fp:
    json.dump(p3_grant_cantons_json, fp, indent=4)

# %%
# The pickle format seems convenients to works with in Python, we're going to use it for transfering data to another notebook
p3_grant_cantons.to_pickle('P3_Cantons.pickle')

# %% [markdown]
# This is the end of the first part. Now that we have linked universities and institutions to cantons, we can start working with the map !

# %% [markdown]
# (2) In this part of the exercise, we now need to put the data which we have procured about the funding levels of the different universities that are located in different cantons onto a canton map. We will do so using Folio and take the example TopoJSON mapping which they use.

# %%
import folium

# Import the Switzerland map (from the folio pylib notebook)
topo_geo = r'ch-cantons.topojson.json'

# Import our csv file with all of the values for the amounts of the grants 
grants_data = pd.read_pickle('P3_Cantons_Sum.pickle')
grants_data['Canton Shortname'] = grants_data.index
grants_data = grants_data.reset_index(drop=True)
grants_data.columns = ['Total Amount','Canton']
grants_data = grants_data[['Canton','Total Amount']]
grants_data['Total Amount'] = (grants_data['Total Amount']).astype(float)

grants_data.head()
#type(grants_data['Total Amount'][1])
# Out:
#   Canton  Total Amount
# 0     AG  2.269557e+08
# 1     BE  1.653339e+09
# 2     BS  1.395041e+09
# 3     FR  4.590737e+08
# 4     GE  1.888685e+09

# %%
# Need to be able to extract the id of the canton from the topo file
from pprint import pprint

with open(topo_geo) as data_file:    
    data = json.load(data_file)
#pprint(data)

#data['objects']['cantons']['geometries']
data['objects']['cantons']['geometries'][0]['id']
# Out:
# 'ZH'

# %%
# Trying to make a list of the key_on BUT NOT WORKING
#length = len(grants_data)
#x = 0
#while (x <= length):
#    key_on = 'objects.cantons.geometries.[' + str(x) + '].id'
#    print(key_on)
#    x += 1

# %%
# Test 1
# We now need to mark the amounts using the Canton abbreviations
ch_map.geo_json(geo_path=topo_geo, 
              data=grants_data,
              columns=['Total Amount', 'Canton'],
              key_on='objects.cantons.geometries.properties.id',
              fill_color='BuPu', 
              fill_opacity=0.7, 
              line_opacity=0.5,
              legend_name='Grants')
display(ch_map)
# Out:
# /Users/paramoed/anaconda/lib/python3.5/site-packages/folium/folium.py:504: UserWarning: This method is deprecated. Please use Map.choropleth instead.
#   warnings.warn('This method is deprecated. '
# /Users/paramoed/anaconda/lib/python3.5/site-packages/folium/folium.py:506: FutureWarning: 'threshold_scale' default behavior has changed. Now you get a linear scale between the 'min' and the 'max' of your data. To get former behavior, use folium.utilities.split_six.
#   return self.choropleth(*args, **kwargs)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-273-af1789eb007e> in <module>()
#       8               fill_opacity=0.7,
#       9               line_opacity=0.5,
# ---> 10               legend_name='Grants')
#      11 display(ch_map)
#
# /Users/paramoed/anaconda/lib/python3.5/site-packages/folium/folium.py in geo_json(self, *args, **kwargs)
#     504         warnings.warn('This method is deprecated. '
#     505                       'Please use Map.choropleth instead.')
# --> 506         return self.choropleth(*args, **kwargs)
#     507
#     508     def choropleth(self, geo_path=None, geo_str=None, data_out='data.json',
#
# /Users/paramoed/anaconda/lib/python3.5/site-packages/folium/folium.py in choropleth(self, geo_path, geo_str, data_out, data, columns, key_on, threshold_scale, fill_color, fill_opacity, line_color, line_weight, line_opacity, legend_name, topojson, reset)
#     640                 data_max = (data_max if data_max > 0 else 0
#     641                             if data_max < 0 else 1)
# --> 642             data_min, data_max = (1.01*data_min-0.01*data_max,
#     643                                   1.01*data_max-0.01*data_min)
#     644             nb_class = 6
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
# Need to overlap the Swiss topo file on the generic Folio map
ch_map = folium.Map(location=[46.9, 8.6], tiles='Mapbox Bright', zoom_start=7)
folium.TopoJson(open(topo_geo), 'objects.cantons', name = 'topojson').add_to(ch_map)
folium.LayerControl().add_to(ch_map)
ch_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>
